# %% [markdown]
# # COVID-19 MIDS Collaboration
#
# ## Data Sourcing: COVID Tracking Project
#
# This Jupyter Notebook reads in raw data as csv files from a website and exports them as [pickle files for faster loading](https://medium.com/better-programming/load-fast-load-big-with-compressed-pickles-5f311584507e).
#
# This code was adapted from a script provided to us by Professor Kevin Crook of the Berkeley MIDS program during our W205 (Data Engineering) class.

# %% [markdown]
# ### Data sources
#
# US COVID-19 data (cumulative, at county level) from the New York Times covid-19 Github repo: https://github.com/nytimes/covid-19-data

# %% [markdown]
# ### Set up environment

# %%
# Import packages
import pandas as pd
import numpy as np
import io
import requests
import pickle

# %% [markdown]
# ### Retrieve data

# %%
# get data at URL - this URL is for the state historical data, updated daily at 4pm ET
r = requests.get("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv")

# %%
# check HTTP request status
r.status_code
# Out:
# 200

# %%
# just show the first 2000 characters, the text is really long otherwise
r.text[0:2000]
# Out:
# 'date,county,state,fips,cases,deaths\n2020-01-21,Snohomish,Washington,53061,1,0\n2020-01-22,Snohomish,Washington,53061,1,0\n2020-01-23,Snohomish,Washington,53061,1,0\n2020-01-24,Cook,Illinois,17031,1,0\n2020-01-24,Snohomish,Washington,53061,1,0\n2020-01-25,Orange,California,06059,1,0\n2020-01-25,Cook,Illinois,17031,1,0\n2020-01-25,Snohomish,Washington,53061,1,0\n2020-01-26,Maricopa,Arizona,04013,1,0\n2020-01-26,Los Angeles,California,06037,1,0\n2020-01-26,Orange,California,06059,1,0\n2020-01-26,Cook,Illinois,17031,1,0\n2020-01-26,Snohomish,Washington,53061,1,0\n2020-01-27,Maricopa,Arizona,04013,1,0\n2020-01-27,Los Angeles,California,06037,1,0\n2020-01-27,Orange,California,06059,1,0\n2020-01-27,Cook,Illinois,17031,1,0\n2020-01-27,Snohomish,Washington,53061,1,0\n2020-01-28,Maricopa,Arizona,04013,1,0\n2020-01-28,Los Angeles,California,06037,1,0\n2020-01-28,Orange,California,06059,1,0\n2020-01-28,Cook,Illinois,17031,1,0\n2020-01-28,Snohomish,Washington,53061,1,0\n2020-01-29,Maricopa,Arizona,04013,1,0\n2020-01-29,Los Angeles,California,06037,1,0\n2020-01-29,Orange,California,06059,1,0\n2020-01-29,Cook,Illinois,17031,1,0\n2020-01-29,Snohomish,Washington,53061,1,0\n2020-01-30,Maricopa,Arizona,04013,1,0\n2020-01-30,Los Angeles,California,06037,1,0\n2020-01-30,Orange,California,06059,1,0\n2020-01-30,Cook,Illinois,17031,2,0\n2020-01-30,Snohomish,Washington,53061,1,0\n2020-01-31,Maricopa,Arizona,04013,1,0\n2020-01-31,Los Angeles,California,06037,1,0\n2020-01-31,Orange,California,06059,1,0\n2020-01-31,Santa Clara,California,06085,1,0\n2020-01-31,Cook,Illinois,17031,2,0\n2020-01-31,Snohomish,Washington,53061,1,0\n2020-02-01,Maricopa,Arizona,04013,1,0\n2020-02-01,Los Angeles,California,06037,1,0\n2020-02-01,Orange,California,06059,1,0\n2020-02-01,Santa Clara,California,06085,1,0\n2020-02-01,Cook,Illinois,17031,2,0\n2020-02-01,Suffolk,Massachusetts,25025,1,0\n2020-02-01,Snohomish,Washington,53061,1,0\n2020-02-02,Maricopa,Arizona,04013,1,0\n2020-02-02,Los Angeles,California,06037,1,0\n2020-02-02,Orange,California,06059,1,0\n2020-02'

# %%
# load into a Pandas dataframe
covid_df = pd.read_csv(io.StringIO(r.text)).add_prefix('o_') 

covid_df
# Out:
#            o_date    o_county     o_state   o_fips  o_cases  o_deaths
# 0      2020-01-21   Snohomish  Washington  53061.0        1         0
# 1      2020-01-22   Snohomish  Washington  53061.0        1         0
# 2      2020-01-23   Snohomish  Washington  53061.0        1         0
# 3      2020-01-24        Cook    Illinois  17031.0        1         0
# 4      2020-01-24   Snohomish  Washington  53061.0        1         0
# ...           ...         ...         ...      ...      ...       ...
# 89767  2020-04-25    Sublette     Wyoming  56035.0        1         0
# 89768  2020-04-25  Sweetwater     Wyoming  56037.0       10         0
# 89769  2020-04-25       Teton     Wyoming  56039.0       64         1
# 89770  2020-04-25       Uinta     Wyoming  56041.0        6         0
# 89771  2020-04-25    Washakie     Wyoming  56043.0        4         0
#
# [89772 rows x 6 columns]

# %% [markdown]
# ### Convert data types

# %% [markdown]
# #### Count records

# %%
# count rows and columns
covid_df.shape
# Out:
# (89772, 6)

# %% [markdown]
# #### Check and convert datatypes

# %% [markdown]
# We have:
#
# * 1 string column tracking the date (which needs to be converted to a date object)
# * 2 string columns tracking location (county, state)
# * 1 float column tracking location (fips) (which should be converted into a category; should also add two columns to have the county and state fips separate)
# * 2 integer columns tracking COVID-19 cases and deaths

# %%
# check data types 
covid_df.dtypes
# Out:
# o_date       object
# o_county     object
# o_state      object
# o_fips      float64
# o_cases       int64
# o_deaths      int64
# dtype: object

# %%
covid_df.head()
# Out:
#        o_date   o_county     o_state   o_fips  o_cases  o_deaths
# 0  2020-01-21  Snohomish  Washington  53061.0        1         0
# 1  2020-01-22  Snohomish  Washington  53061.0        1         0
# 2  2020-01-23  Snohomish  Washington  53061.0        1         0
# 3  2020-01-24       Cook    Illinois  17031.0        1         0
# 4  2020-01-24  Snohomish  Washington  53061.0        1         0

# %%
# create new version of column as a datetime object
covid_df["date"] = pd.to_datetime(covid_df["o_date"])
# check conversion 
covid_df.dtypes
# Out:
# o_date              object
# o_county            object
# o_state             object
# o_fips             float64
# o_cases              int64
# o_deaths             int64
# date        datetime64[ns]
# dtype: object

# %%
# create new version of fips column as a category (must convert to integer as in-between step)
covid_df["fips"] = covid_df["o_fips"].astype('Int64').astype('category')
# check conversion 
covid_df.dtypes
# Out:
# o_date              object
# o_county            object
# o_state             object
# o_fips             float64
# o_cases              int64
# o_deaths             int64
# date        datetime64[ns]
# fips              category
# dtype: object

# %%
# visual check of column conversions - these worked 
covid_df.head()
# Out:
#        o_date   o_county     o_state   o_fips  o_cases  o_deaths       date  \
# 0  2020-01-21  Snohomish  Washington  53061.0        1         0 2020-01-21
# 1  2020-01-22  Snohomish  Washington  53061.0        1         0 2020-01-22
# 2  2020-01-23  Snohomish  Washington  53061.0        1         0 2020-01-23
# 3  2020-01-24       Cook    Illinois  17031.0        1         0 2020-01-24
# 4  2020-01-24  Snohomish  Washington  53061.0        1         0 2020-01-24
#
#     fips
# 0  53061
# 1  53061
# 2  53061
# 3  17031
# 4  53061

# %% [markdown]
# ### Check missingness

# %% [markdown]
# We have some missing FIPS codes, but no other missing data (at least that is coded as NaNs).

# %%
covid_df.isnull().sum(axis = 0)
# Out:
# o_date         0
# o_county       0
# o_state        0
# o_fips      1097
# o_cases        0
# o_deaths       0
# date           0
# fips        1097
# dtype: int64

# %% [markdown]
# 3 counties have missing FIPS codes.

# %%
covid_df["o_county"][covid_df["o_fips"].isnull()].unique()
# Out:
# array(['New York City', 'Unknown', 'Kansas City'], dtype=object)

# %% [markdown]
# New York City is comprised of 5 counties (1 for each of the 5 boroughs); these each have their own FIPS codes: New York County (Manhattan), Kings County (Brooklyn), Bronx County (The Bronx), Richmond County (Staten Island), and Queens County (Queens).
#
# This is documented in the NYT github repo: All cases for the five boroughs of New York City (New York, Kings, Queens, Bronx and Richmond counties) are assigned to a single area called New York City. There is a large jump in the number of deaths on April 6th due to switching from data from New York City to data from New York state for deaths. We are not currently including the probable deaths reported by New York City.

# %%
# show unique state for counties coded as "Unknown"
covid_df["o_state"][covid_df["o_county"] == "New York City"].unique()
# Out:
# array(['New York'], dtype=object)

# %%
# show unique fips codes for counties coded as "New York City"
covid_df["o_fips"][covid_df["o_county"] == "New York City"].unique()
# Out:
# array([nan])

# %% [markdown]
# Kansas City, Missouri also straddles multiple counties which would explain why it does not have a FIPS code.
#
# This is documented in the NYT github repo: Four counties (Cass, Clay, Jackson and Platte) overlap the municipality of Kansas City, Mo. The cases and deaths that we show for these four counties are only for the portions exclusive of Kansas City. Cases and deaths for Kansas City are reported as their own line.

# %%
# show unique states for counties coded as "Kansas City"
covid_df["o_state"][covid_df["o_county"] == "Kansas City"].unique()
# Out:
# array(['Missouri'], dtype=object)

# %%
# show unique fips codes for counties coded as "Kansas City"
covid_df["o_fips"][covid_df["o_county"] == "Kansas City"].unique()
# Out:
# array([nan])

# %% [markdown]
# Other rows are missing FIPS codes because they lack a county (it is marked as "Unknown"). Some would make sense - for example, Puerto Rico only has a state FIPS code.
#
# This is the documentation from the NYT: Many state health departments choose to report cases separately when the patient’s county of residence is unknown or pending determination. In these instances, we record the county name as “Unknown.” As more information about these cases becomes available, the cumulative number of cases in “Unknown” counties may fluctuate.
#
# Sometimes, cases are first reported in one county and then moved to another county. As a result, the cumulative number of cases may change for a given county.

# %%
# show unique states for counties coded as "Unknown"
covid_df["o_state"][covid_df["o_county"] == "Unknown"].unique()
# Out:
# array(['Rhode Island', 'New Jersey', 'Puerto Rico', 'Virgin Islands',
#        'Guam', 'Maine', 'Massachusetts', 'Louisiana', 'Kentucky',
#        'Nevada', 'Tennessee', 'Arkansas', 'Georgia', 'Missouri',
#        'Minnesota', 'California', 'Colorado', 'Florida', 'Hawaii',
#        'Illinois', 'Vermont', 'Idaho', 'Michigan', 'Ohio', 'Utah',
#        'Mississippi', 'Northern Mariana Islands', 'Nebraska',
#        'Connecticut', 'Indiana', 'Alaska', 'Arizona', 'New Mexico',
#        'New York', 'Pennsylvania', 'Virginia', 'New Hampshire',
#        'South Dakota', 'Washington', 'Delaware', 'Kansas', 'North Dakota',
#        'Maryland', 'Iowa'], dtype=object)

# %%
# show unique fips codes for counties coded as "Unknown"
covid_df["o_fips"][covid_df["o_county"] == "Unknown"].unique()
# Out:
# array([nan])

# %% [markdown]
# The missingness in FIPS codes is a major issue since this is the geographic identifier we would use to join these data to other datsets. We will likely need to accurately rectify this missingness in order to accurately combine our data. These don't seem to be erroneous data for the most part. Rather, the missing points reflect when a data point is at the city (rather than county) level and/or if there is no county for that region.

# %%
# replace rows with missing county with NaN 
covid_df["county"] = covid_df["o_county"].replace("Unknown", None)

# %% [markdown]
# ### Generate summary statistics

# %% [markdown]
# The mins and maxes look reasonable for COVID-19 mins and maxes. The distributions are remarkable but also reasonable - we clearly have some outliers on the high end (New York is likely one of those).
#
# We have no missing data in the text columns. We have data for 86 unique days, in 55 "states" (so the data also include territories), and 1,627 counties. In the original county column, we see there are 1,628 unique values since the NaNs used to be coded as "Unknown".
#
# We can see that we have some missing data in our FIPS codes column and that we have 2,708 unique codes.
#
# Our earliest date was January 21st, 2020. Our last was April 15th, 2020.

# %%
# display summary statistics
covid_df.describe(include = 'all')
# Out:
#             o_date    o_county o_state        o_fips        o_cases  \
# count        89772       89772   89772  88675.000000   89772.000000
# unique          96        1673      55           NaN            NaN
# top     2020-04-25  Washington   Texas           NaN            NaN
# freq          2820        1072    5665           NaN            NaN
# first          NaN         NaN     NaN           NaN            NaN
# last           NaN         NaN     NaN           NaN            NaN
# mean           NaN         NaN     NaN  29773.602729     172.927104
# std            NaN         NaN     NaN  15466.678766    2079.570699
# min            NaN         NaN     NaN   1001.000000       0.000000
# 25%            NaN         NaN     NaN  18013.000000       2.000000
# 50%            NaN         NaN     NaN  29001.000000       8.000000
# 75%            NaN         NaN     NaN  45007.000000      36.000000
# max            NaN         NaN     NaN  56043.000000  155124.000000
#
#             o_deaths                 date     fips      county
# count   89772.000000                89772  88675.0       89772
# unique           NaN                   96   2807.0        1672
# top              NaN  2020-04-25 00:00:00  53061.0  Washington
# freq             NaN                 2820     96.0        1077
# first            NaN  2020-01-21 00:00:00      NaN         NaN
# last             NaN  2020-04-25 00:00:00      NaN         NaN
# mean        7.172593                  NaN      NaN         NaN
# std       131.810249                  NaN      NaN         NaN
# min         0.000000                  NaN      NaN         NaN
# 25%         0.000000                  NaN      NaN         NaN
# 50%         0.000000                  NaN      NaN         NaN
# 75%         1.000000                  NaN      NaN         NaN
# max     11419.000000                  NaN      NaN         NaN

# %% [markdown]
# Now that we have verified our column conversion worked, we drop the columns for which we had added additional columns with the correct data type and remove the "o_" prefix since we no longer need to compare original versus converted columns. Columns are reordered to match the original ordering in the dataset.

# %%
# drop, rename, and reorder columns
converted_covid_df = covid_df.drop(columns = ["o_date", "o_fips", "o_county"]).rename(columns = lambda x: x.replace('o_', ''))[["date", "fips", "state", "county", "cases", "deaths"]]
# visual inspection
converted_covid_df.head()
# Out:
#         date   fips       state     county  cases  deaths
# 0 2020-01-21  53061  Washington  Snohomish      1       0
# 1 2020-01-22  53061  Washington  Snohomish      1       0
# 2 2020-01-23  53061  Washington  Snohomish      1       0
# 3 2020-01-24  17031    Illinois       Cook      1       0
# 4 2020-01-24  53061  Washington  Snohomish      1       0

# %% [markdown]
# ### Check duplicates

# %% [markdown]
# There are no perfectly duplicated rows.

# %%
sum(converted_covid_df.duplicated())
# Out:
# 0

# %%
# create column to store county-state pairs
converted_covid_df["county_state"] = (converted_covid_df["county"] + ", " + converted_covid_df["state"])
# count unique county-state pairs
len(converted_covid_df["county_state"].unique())
# Out:
# 2820

# %% [markdown]
# Suffolk, Massachusetts appears the most frequently, which is unexpected. It has 20 more entries than there are days in the dataset. The next county is Snohomish, Washington at a rate that would represent one record per day. Some areas appear only once.

# %%
converted_covid_df["county_state"].value_counts()
# Out:
# Suffolk, Massachusetts    126
# Snohomish, Washington      96
# Cook, Illinois             93
# Union, New Jersey          93
# Orange, California         92
#                          ...
# San Juan, Colorado          1
# Pembina, North Dakota       1
# Gilmer, West Virginia       1
# Hidalgo, New Mexico         1
# Butte, South Dakota         1
# Name: county_state, Length: 2820, dtype: int64

# %% [markdown]
# Suffolk, Massachusettes has duplicates of daily counts.

# %%
len(converted_covid_df["date"][converted_covid_df["county_state"] == "Suffolk, Massachusetts"].unique())
# Out:
# 85

# %% [markdown]
# We can see that the maximum number of unique dates is for Snohomish, Washington. We will need to flatten our file so that it is at the date level - so that there is one date per county/state pair.

# %%
# show first 5 rows of dataframe
converted_covid_df.groupby('county_state').date.nunique().reset_index().sort_values('date', ascending = 0).head(5)
# Out:
#                  county_state  date
# 2342    Snohomish, Washington    96
# 567            Cook, Illinois    93
# 1917       Orange, California    92
# 1518  Los Angeles, California    91
# 1586        Maricopa, Arizona    91

# %%
# show first 5 rows of dataframe
converted_covid_df.groupby('county_state').date.nunique().reset_index().sort_values('date', ascending = 0).tail(5)
# Out:
#                  county_state  date
# 1118      Hidalgo, New Mexico     1
# 662         Day, South Dakota     1
# 658           Dawes, Nebraska     1
# 1569  Madison, North Carolina     1
# 928     Gilmer, West Virginia     1

# %%
converted_covid_df[converted_covid_df.duplicated(subset=['county_state', 'date'], keep=False)]
# Out:
#             date   fips         state      county  cases  deaths  \
# 1510  2020-03-12  34039    New Jersey       Union      1       0
# 1511  2020-03-12    NaN    New Jersey       Union      1       0
# 1803  2020-03-13  34039    New Jersey       Union      1       0
# 1804  2020-03-13    NaN    New Jersey       Union      1       0
# 2150  2020-03-14  34039    New Jersey       Union      1       0
# ...          ...    ...           ...         ...    ...     ...
# 89042 2020-04-25    NaN  Rhode Island  Providence   1198      96
# 89448 2020-04-25  49047          Utah      Uintah      6       0
# 89449 2020-04-25    NaN          Utah      Uintah      0       1
# 89464 2020-04-25  50021       Vermont     Rutland     44       1
# 89465 2020-04-25    NaN       Vermont     Rutland      5       0
#
#                    county_state
# 1510          Union, New Jersey
# 1511          Union, New Jersey
# 1803          Union, New Jersey
# 1804          Union, New Jersey
# 2150          Union, New Jersey
# ...                         ...
# 89042  Providence, Rhode Island
# 89448              Uintah, Utah
# 89449              Uintah, Utah
# 89464          Rutland, Vermont
# 89465          Rutland, Vermont
#
# [1644 rows x 7 columns]

# %% [markdown]
# If these duplicated rows have about 1 extra duplication each, we would expect to drop the following number of rows when we flatten:

# %%
converted_covid_df[converted_covid_df.duplicated(subset=['county_state', 'date'], keep=False)].shape[0]/2
# Out:
# 822.0

# %% [markdown]
# We can see that there are discrepancies in case counts on some days  in some counties. It is unclear whether we should add these cases or if one row is accurate.

# %%
# pull out rows for Thurston County, Washington
converted_covid_df[(converted_covid_df['county'] == 'Thurston') & (converted_covid_df['state'] == 'Washington')]
# Out:
#             date   fips       state    county  cases  deaths  \
# 1356  2020-03-11  53067  Washington  Thurston      1       0
# 1610  2020-03-12  53067  Washington  Thurston      1       0
# 1921  2020-03-13  53067  Washington  Thurston      3       0
# 2295  2020-03-14  53067  Washington  Thurston      3       0
# 2724  2020-03-15  53067  Washington  Thurston      4       0
# 3198  2020-03-16  53067  Washington  Thurston      4       0
# 3740  2020-03-17  53067  Washington  Thurston      5       0
# 4375  2020-03-18  53067  Washington  Thurston      6       0
# 5132  2020-03-19  53067  Washington  Thurston      6       0
# 6036  2020-03-20  53067  Washington  Thurston      8       0
# 7067  2020-03-21  53067  Washington  Thurston     10       0
# 8204  2020-03-22  53067  Washington  Thurston     11       0
# 9430  2020-03-23  53067  Washington  Thurston     11       0
# 10783 2020-03-24  53067  Washington  Thurston     14       0
# 12312 2020-03-25  53067  Washington  Thurston     14       0
# 13974 2020-03-26  53067  Washington  Thurston     24       0
# 15755 2020-03-27  53067  Washington  Thurston     27       0
# 17647 2020-03-28  53067  Washington  Thurston     33       0
# 19626 2020-03-29  53067  Washington  Thurston     36       0
# 21706 2020-03-30  53067  Washington  Thurston     43       0
# 23869 2020-03-31  53067  Washington  Thurston     48       0
# 26097 2020-04-01  53067  Washington  Thurston     51       0
# 28383 2020-04-02  53067  Washington  Thurston     55       0
# 30735 2020-04-03  53067  Washington  Thurston     58       0
# 33137 2020-04-04  53067  Washington  Thurston     64       1
# 35578 2020-04-05  53067  Washington  Thurston     67       1
# 38062 2020-04-06  53067  Washington  Thurston     72       1
# 38063 2020-04-06    NaN  Washington  Thurston    653       0
# 40594 2020-04-07  53067  Washington  Thurston     74       1
# 40595 2020-04-07    NaN  Washington  Thurston    601       0
# 43157 2020-04-08  53067  Washington  Thurston     77       1
# 43158 2020-04-08    NaN  Washington  Thurston    705       0
# 45748 2020-04-09  53067  Washington  Thurston     81       1
# 45749 2020-04-09    NaN  Washington  Thurston    815       0
# 48375 2020-04-10  53067  Washington  Thurston     81       1
# 48376 2020-04-10    NaN  Washington  Thurston    627       0
# 51032 2020-04-11  53067  Washington  Thurston     81       1
# 51033 2020-04-11    NaN  Washington  Thurston    583       0
# 53708 2020-04-12  53067  Washington  Thurston     81       1
# 53709 2020-04-12    NaN  Washington  Thurston    499       0
# 56400 2020-04-13  53067  Washington  Thurston     81       1
# 56401 2020-04-13    NaN  Washington  Thurston    329       0
# 59106 2020-04-14  53067  Washington  Thurston     82       1
# 59107 2020-04-14    NaN  Washington  Thurston    220       0
# 61828 2020-04-15  53067  Washington  Thurston     82       1
# 61829 2020-04-15    NaN  Washington  Thurston     77       0
# 64563 2020-04-16  53067  Washington  Thurston     86       1
# 64564 2020-04-16    NaN  Washington  Thurston    154       0
# 67313 2020-04-17  53067  Washington  Thurston     89       1
# 67314 2020-04-17    NaN  Washington  Thurston    174       0
# 70075 2020-04-18  53067  Washington  Thurston     93       1
# 70076 2020-04-18    NaN  Washington  Thurston    233       0
# 72845 2020-04-19  53067  Washington  Thurston     94       1
# 72846 2020-04-19    NaN  Washington  Thurston      1       0
# 75623 2020-04-20  53067  Washington  Thurston     94       1
# 78406 2020-04-21  53067  Washington  Thurston     94       1
# 81200 2020-04-22  53067  Washington  Thurston     95       1
# 84003 2020-04-23  53067  Washington  Thurston     96       1
# 86811 2020-04-24  53067  Washington  Thurston     98       1
# 89630 2020-04-25  53067  Washington  Thurston    101       1
#
#                county_state
# 1356   Thurston, Washington
# 1610   Thurston, Washington
# 1921   Thurston, Washington
# 2295   Thurston, Washington
# 2724   Thurston, Washington
# 3198   Thurston, Washington
# 3740   Thurston, Washington
# 4375   Thurston, Washington
# 5132   Thurston, Washington
# 6036   Thurston, Washington
# 7067   Thurston, Washington
# 8204   Thurston, Washington
# 9430   Thurston, Washington
# 10783  Thurston, Washington
# 12312  Thurston, Washington
# 13974  Thurston, Washington
# 15755  Thurston, Washington
# 17647  Thurston, Washington
# 19626  Thurston, Washington
# 21706  Thurston, Washington
# 23869  Thurston, Washington
# 26097  Thurston, Washington
# 28383  Thurston, Washington
# 30735  Thurston, Washington
# 33137  Thurston, Washington
# 35578  Thurston, Washington
# 38062  Thurston, Washington
# 38063  Thurston, Washington
# 40594  Thurston, Washington
# 40595  Thurston, Washington
# 43157  Thurston, Washington
# 43158  Thurston, Washington
# 45748  Thurston, Washington
# 45749  Thurston, Washington
# 48375  Thurston, Washington
# 48376  Thurston, Washington
# 51032  Thurston, Washington
# 51033  Thurston, Washington
# 53708  Thurston, Washington
# 53709  Thurston, Washington
# 56400  Thurston, Washington
# 56401  Thurston, Washington
# 59106  Thurston, Washington
# 59107  Thurston, Washington
# 61828  Thurston, Washington
# 61829  Thurston, Washington
# 64563  Thurston, Washington
# 64564  Thurston, Washington
# 67313  Thurston, Washington
# 67314  Thurston, Washington
# 70075  Thurston, Washington
# 70076  Thurston, Washington
# 72845  Thurston, Washington
# 72846  Thurston, Washington
# 75623  Thurston, Washington
# 78406  Thurston, Washington
# 81200  Thurston, Washington
# 84003  Thurston, Washington
# 86811  Thurston, Washington
# 89630  Thurston, Washington

# %% [markdown]
# ### Convert to appropriate level

# %% [markdown]
# Here, we flatten the file so that there is one row per county-state pair for each day. We sum over the cases and deaths for that day to generate a new cases and deaths column.

# %%
# create new dataframe flattened to county-state pair and date level 
flattened_covid_df = converted_covid_df.groupby(['county_state', 'date']).agg(
    {
     'state': 'first',
     'county': 'first',
     'fips': np.unique,
     'cases':np.unique, 
     'deaths':np.unique
    }).reset_index()

# %%
flattened_covid_df.head()
# Out:
#                 county_state       date           state     county     fips  \
# 0  Abbeville, South Carolina 2020-03-19  South Carolina  Abbeville  [45001]
# 1  Abbeville, South Carolina 2020-03-20  South Carolina  Abbeville  [45001]
# 2  Abbeville, South Carolina 2020-03-21  South Carolina  Abbeville  [45001]
# 3  Abbeville, South Carolina 2020-03-22  South Carolina  Abbeville  [45001]
# 4  Abbeville, South Carolina 2020-03-23  South Carolina  Abbeville  [45001]
#
#   cases deaths
# 0     1      0
# 1     1      0
# 2     1      0
# 3     1      0
# 4     1      0

# %% [markdown]
# We can see that for counties with discrepancies in case counts, the different case counts are put into a list. These may need to be cleaned manually.

# %%
flattened_covid_df[(flattened_covid_df['county'] == 'Thurston') & (flattened_covid_df['state'] == 'Washington')]
# Out:
#                county_state       date       state    county            fips  \
# 78468  Thurston, Washington 2020-03-11  Washington  Thurston         [53067]
# 78469  Thurston, Washington 2020-03-12  Washington  Thurston         [53067]
# 78470  Thurston, Washington 2020-03-13  Washington  Thurston         [53067]
# 78471  Thurston, Washington 2020-03-14  Washington  Thurston         [53067]
# 78472  Thurston, Washington 2020-03-15  Washington  Thurston         [53067]
# 78473  Thurston, Washington 2020-03-16  Washington  Thurston         [53067]
# 78474  Thurston, Washington 2020-03-17  Washington  Thurston         [53067]
# 78475  Thurston, Washington 2020-03-18  Washington  Thurston         [53067]
# 78476  Thurston, Washington 2020-03-19  Washington  Thurston         [53067]
# 78477  Thurston, Washington 2020-03-20  Washington  Thurston         [53067]
# 78478  Thurston, Washington 2020-03-21  Washington  Thurston         [53067]
# 78479  Thurston, Washington 2020-03-22  Washington  Thurston         [53067]
# 78480  Thurston, Washington 2020-03-23  Washington  Thurston         [53067]
# 78481  Thurston, Washington 2020-03-24  Washington  Thurston         [53067]
# 78482  Thurston, Washington 2020-03-25  Washington  Thurston         [53067]
# 78483  Thurston, Washington 2020-03-26  Washington  Thurston         [53067]
# 78484  Thurston, Washington 2020-03-27  Washington  Thurston         [53067]
# 78485  Thurston, Washington 2020-03-28  Washington  Thurston         [53067]
# 78486  Thurston, Washington 2020-03-29  Washington  Thurston         [53067]
# 78487  Thurston, Washington 2020-03-30  Washington  Thurston         [53067]
# 78488  Thurston, Washington 2020-03-31  Washington  Thurston         [53067]
# 78489  Thurston, Washington 2020-04-01  Washington  Thurston         [53067]
# 78490  Thurston, Washington 2020-04-02  Washington  Thurston         [53067]
# 78491  Thurston, Washington 2020-04-03  Washington  Thurston         [53067]
# 78492  Thurston, Washington 2020-04-04  Washington  Thurston         [53067]
# 78493  Thurston, Washington 2020-04-05  Washington  Thurston         [53067]
# 78494  Thurston, Washington 2020-04-06  Washington  Thurston  [53067.0, nan]
# 78495  Thurston, Washington 2020-04-07  Washington  Thurston  [53067.0, nan]
# 78496  Thurston, Washington 2020-04-08  Washington  Thurston  [53067.0, nan]
# 78497  Thurston, Washington 2020-04-09  Washington  Thurston  [53067.0, nan]
# 78498  Thurston, Washington 2020-04-10  Washington  Thurston  [53067.0, nan]
# 78499  Thurston, Washington 2020-04-11  Washington  Thurston  [53067.0, nan]
# 78500  Thurston, Washington 2020-04-12  Washington  Thurston  [53067.0, nan]
# 78501  Thurston, Washington 2020-04-13  Washington  Thurston  [53067.0, nan]
# 78502  Thurston, Washington 2020-04-14  Washington  Thurston  [53067.0, nan]
# 78503  Thurston, Washington 2020-04-15  Washington  Thurston  [53067.0, nan]
# 78504  Thurston, Washington 2020-04-16  Washington  Thurston  [53067.0, nan]
# 78505  Thurston, Washington 2020-04-17  Washington  Thurston  [53067.0, nan]
# 78506  Thurston, Washington 2020-04-18  Washington  Thurston  [53067.0, nan]
# 78507  Thurston, Washington 2020-04-19  Washington  Thurston  [53067.0, nan]
# 78508  Thurston, Washington 2020-04-20  Washington  Thurston         [53067]
# 78509  Thurston, Washington 2020-04-21  Washington  Thurston         [53067]
# 78510  Thurston, Washington 2020-04-22  Washington  Thurston         [53067]
# 78511  Thurston, Washington 2020-04-23  Washington  Thurston         [53067]
# 78512  Thurston, Washington 2020-04-24  Washington  Thurston         [53067]
# 78513  Thurston, Washington 2020-04-25  Washington  Thurston         [53067]
#
#            cases  deaths
# 78468          1       0
# 78469          1       0
# 78470          3       0
# 78471          3       0
# 78472          4       0
# 78473          4       0
# 78474          5       0
# 78475          6       0
# 78476          6       0
# 78477          8       0
# 78478         10       0
# 78479         11       0
# 78480         11       0
# 78481         14       0
# 78482         14       0
# 78483         24       0
# 78484         27       0
# 78485         33       0
# 78486         36       0
# 78487         43       0
# 78488         48       0
# 78489         51       0
# 78490         55       0
# 78491         58       0
# 78492         64       1
# 78493         67       1
# 78494  [72, 653]  [0, 1]
# 78495  [74, 601]  [0, 1]
# 78496  [77, 705]  [0, 1]
# 78497  [81, 815]  [0, 1]
# 78498  [81, 627]  [0, 1]
# 78499  [81, 583]  [0, 1]
# 78500  [81, 499]  [0, 1]
# 78501  [81, 329]  [0, 1]
# 78502  [82, 220]  [0, 1]
# 78503   [77, 82]  [0, 1]
# 78504  [86, 154]  [0, 1]
# 78505  [89, 174]  [0, 1]
# 78506  [93, 233]  [0, 1]
# 78507    [1, 94]  [0, 1]
# 78508         94       1
# 78509         94       1
# 78510         95       1
# 78511         96       1
# 78512         98       1
# 78513        101       1

# %% [markdown]
# The fips column can be split into a column of fips and a column of NAs because some rows had the county-state identifier and date but did not have a fips code.

# %%
# split columns
flattened_covid_df[['fips','fips0']] = pd.DataFrame(flattened_covid_df.fips.values.tolist(), index= flattened_covid_df.index)

# change back data type of fips column
flattened_covid_df['fips'] = flattened_covid_df['fips'].astype('Int64').astype('category')

# check that new column is only NAs 
sum(flattened_covid_df['fips0'].notna())
# Out:
# 0

# %%
# create new version of fips column as string 
flattened_covid_df["fips_str"] = flattened_covid_df["fips"].astype('str')

# %%
# extract state FIPS and convert to category 
flattened_covid_df["state_fips"] = flattened_covid_df["fips_str"].apply(lambda x: x[:-3]).astype('category')
flattened_covid_df["state_fips"].head()
# Out:
# 0    4500
# 1    4500
# 2    4500
# 3    4500
# 4    4500
# Name: state_fips, dtype: category
# Categories (682, object): [, 100, 1000, 101, ..., 811, 812, 900, 901]

# %%
# extract county FIPS and convert to category 
flattened_covid_df["county_fips"] = flattened_covid_df["fips_str"].apply(lambda x: x[-3:]).astype('category')
flattened_covid_df["county_fips"].head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: county_fips, dtype: category
# Categories (11, object): [0.0, 1.0, 2.0, 3.0, ..., 7.0, 8.0, 9.0, nan]

# %%
# drop superfluous, newly added columns
flattened_covid_df = flattened_covid_df.drop(columns = ['fips0', 'fips_str'])

# %%
# recheck data types
flattened_covid_df.dtypes
# Out:
# county_state            object
# date            datetime64[ns]
# state                   object
# county                  object
# fips                  category
# cases                   object
# deaths                  object
# state_fips            category
# county_fips           category
# dtype: object

# %% [markdown]
# We can see that we have dropped around the number of rows we expected to drop in flattening the files.

# %%
# check new shape
covid_df.shape[0] - flattened_covid_df.shape[0]
# Out:
# 822

# %%
# inspect new dataframe 
flattened_covid_df.head()
# Out:
#                 county_state       date           state     county   fips  \
# 0  Abbeville, South Carolina 2020-03-19  South Carolina  Abbeville  45001
# 1  Abbeville, South Carolina 2020-03-20  South Carolina  Abbeville  45001
# 2  Abbeville, South Carolina 2020-03-21  South Carolina  Abbeville  45001
# 3  Abbeville, South Carolina 2020-03-22  South Carolina  Abbeville  45001
# 4  Abbeville, South Carolina 2020-03-23  South Carolina  Abbeville  45001
#
#   cases deaths state_fips county_fips
# 0     1      0       4500         1.0
# 1     1      0       4500         1.0
# 2     1      0       4500         1.0
# 3     1      0       4500         1.0
# 4     1      0       4500         1.0

# %%
# reorder columns
flattened_covid_df = flattened_covid_df[['date', 'county_state', 'state', 'county', 'fips', 'state_fips', 'county_fips', 
                                       'cases', 'deaths']]
flattened_covid_df.head()
# Out:
#         date               county_state           state     county   fips  \
# 0 2020-03-19  Abbeville, South Carolina  South Carolina  Abbeville  45001
# 1 2020-03-20  Abbeville, South Carolina  South Carolina  Abbeville  45001
# 2 2020-03-21  Abbeville, South Carolina  South Carolina  Abbeville  45001
# 3 2020-03-22  Abbeville, South Carolina  South Carolina  Abbeville  45001
# 4 2020-03-23  Abbeville, South Carolina  South Carolina  Abbeville  45001
#
#   state_fips county_fips cases deaths
# 0       4500         1.0     1      0
# 1       4500         1.0     1      0
# 2       4500         1.0     1      0
# 3       4500         1.0     1      0
# 4       4500         1.0     1      0

# %%
# check Thurston, Washington again
flattened_covid_df[(flattened_covid_df['county'] == 'Thurston') & (flattened_covid_df['state'] == 'Washington')]
# Out:
#             date          county_state       state    county   fips  \
# 78468 2020-03-11  Thurston, Washington  Washington  Thurston  53067
# 78469 2020-03-12  Thurston, Washington  Washington  Thurston  53067
# 78470 2020-03-13  Thurston, Washington  Washington  Thurston  53067
# 78471 2020-03-14  Thurston, Washington  Washington  Thurston  53067
# 78472 2020-03-15  Thurston, Washington  Washington  Thurston  53067
# 78473 2020-03-16  Thurston, Washington  Washington  Thurston  53067
# 78474 2020-03-17  Thurston, Washington  Washington  Thurston  53067
# 78475 2020-03-18  Thurston, Washington  Washington  Thurston  53067
# 78476 2020-03-19  Thurston, Washington  Washington  Thurston  53067
# 78477 2020-03-20  Thurston, Washington  Washington  Thurston  53067
# 78478 2020-03-21  Thurston, Washington  Washington  Thurston  53067
# 78479 2020-03-22  Thurston, Washington  Washington  Thurston  53067
# 78480 2020-03-23  Thurston, Washington  Washington  Thurston  53067
# 78481 2020-03-24  Thurston, Washington  Washington  Thurston  53067
# 78482 2020-03-25  Thurston, Washington  Washington  Thurston  53067
# 78483 2020-03-26  Thurston, Washington  Washington  Thurston  53067
# 78484 2020-03-27  Thurston, Washington  Washington  Thurston  53067
# 78485 2020-03-28  Thurston, Washington  Washington  Thurston  53067
# 78486 2020-03-29  Thurston, Washington  Washington  Thurston  53067
# 78487 2020-03-30  Thurston, Washington  Washington  Thurston  53067
# 78488 2020-03-31  Thurston, Washington  Washington  Thurston  53067
# 78489 2020-04-01  Thurston, Washington  Washington  Thurston  53067
# 78490 2020-04-02  Thurston, Washington  Washington  Thurston  53067
# 78491 2020-04-03  Thurston, Washington  Washington  Thurston  53067
# 78492 2020-04-04  Thurston, Washington  Washington  Thurston  53067
# 78493 2020-04-05  Thurston, Washington  Washington  Thurston  53067
# 78494 2020-04-06  Thurston, Washington  Washington  Thurston  53067
# 78495 2020-04-07  Thurston, Washington  Washington  Thurston  53067
# 78496 2020-04-08  Thurston, Washington  Washington  Thurston  53067
# 78497 2020-04-09  Thurston, Washington  Washington  Thurston  53067
# 78498 2020-04-10  Thurston, Washington  Washington  Thurston  53067
# 78499 2020-04-11  Thurston, Washington  Washington  Thurston  53067
# 78500 2020-04-12  Thurston, Washington  Washington  Thurston  53067
# 78501 2020-04-13  Thurston, Washington  Washington  Thurston  53067
# 78502 2020-04-14  Thurston, Washington  Washington  Thurston  53067
# 78503 2020-04-15  Thurston, Washington  Washington  Thurston  53067
# 78504 2020-04-16  Thurston, Washington  Washington  Thurston  53067
# 78505 2020-04-17  Thurston, Washington  Washington  Thurston  53067
# 78506 2020-04-18  Thurston, Washington  Washington  Thurston  53067
# 78507 2020-04-19  Thurston, Washington  Washington  Thurston  53067
# 78508 2020-04-20  Thurston, Washington  Washington  Thurston  53067
# 78509 2020-04-21  Thurston, Washington  Washington  Thurston  53067
# 78510 2020-04-22  Thurston, Washington  Washington  Thurston  53067
# 78511 2020-04-23  Thurston, Washington  Washington  Thurston  53067
# 78512 2020-04-24  Thurston, Washington  Washington  Thurston  53067
# 78513 2020-04-25  Thurston, Washington  Washington  Thurston  53067
#
#       state_fips county_fips      cases  deaths
# 78468       5306         7.0          1       0
# 78469       5306         7.0          1       0
# 78470       5306         7.0          3       0
# 78471       5306         7.0          3       0
# 78472       5306         7.0          4       0
# 78473       5306         7.0          4       0
# 78474       5306         7.0          5       0
# 78475       5306         7.0          6       0
# 78476       5306         7.0          6       0
# 78477       5306         7.0          8       0
# 78478       5306         7.0         10       0
# 78479       5306         7.0         11       0
# 78480       5306         7.0         11       0
# 78481       5306         7.0         14       0
# 78482       5306         7.0         14       0
# 78483       5306         7.0         24       0
# 78484       5306         7.0         27       0
# 78485       5306         7.0         33       0
# 78486       5306         7.0         36       0
# 78487       5306         7.0         43       0
# 78488       5306         7.0         48       0
# 78489       5306         7.0         51       0
# 78490       5306         7.0         55       0
# 78491       5306         7.0         58       0
# 78492       5306         7.0         64       1
# 78493       5306         7.0         67       1
# 78494       5306         7.0  [72, 653]  [0, 1]
# 78495       5306         7.0  [74, 601]  [0, 1]
# 78496       5306         7.0  [77, 705]  [0, 1]
# 78497       5306         7.0  [81, 815]  [0, 1]
# 78498       5306         7.0  [81, 627]  [0, 1]
# 78499       5306         7.0  [81, 583]  [0, 1]
# 78500       5306         7.0  [81, 499]  [0, 1]
# 78501       5306         7.0  [81, 329]  [0, 1]
# 78502       5306         7.0  [82, 220]  [0, 1]
# 78503       5306         7.0   [77, 82]  [0, 1]
# 78504       5306         7.0  [86, 154]  [0, 1]
# 78505       5306         7.0  [89, 174]  [0, 1]
# 78506       5306         7.0  [93, 233]  [0, 1]
# 78507       5306         7.0    [1, 94]  [0, 1]
# 78508       5306         7.0         94       1
# 78509       5306         7.0         94       1
# 78510       5306         7.0         95       1
# 78511       5306         7.0         96       1
# 78512       5306         7.0         98       1
# 78513       5306         7.0        101       1

# %%
pd.DataFrame(flattened_covid_df.cases.values.tolist(), index= flattened_covid_df.index)
# Out:
#        0
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ...   ..
# 88945  1
# 88946  1
# 88947  1
# 88948  1
# 88949  1
#
# [88950 rows x 1 columns]

# %% [markdown]
# ### Pickle data

# %%
# pickle both flattened & unflattened version
pickle.dump(converted_covid_df, open( "../Data_pkl/covid19/nyt_converted_covid_df.pkl", "wb" ) )
pickle.dump(flattened_covid_df, open( "../Data_pkl/covid19/nyt_flattened_covid_df.pkl", "wb" ) )
