# %% [markdown]
# # COVID-19 MIDS Collaboration
#
# ## Data Sourcing: COVID Tracking Project
#
# This Jupyter Notebook reads in raw data as csv files from a website and exports them as [pickle files for faster loading](https://medium.com/better-programming/load-fast-load-big-with-compressed-pickles-5f311584507e).
#
# This code was adapted from a script provided to us by Professor Kevin Crook of the Berkeley MIDS program during our W205 (Data Engineering) class.

# %% [markdown]
# ### Data sources
#
# US COVID-19 data (historical, at state level) from the COVID tracking project: https://covidtracking.com/api
#
# Note: they are a new website, and their file formats have changed several times, but will eventually settle down.  So the parsing may change.

# %% [markdown]
# ### Set up environment

# %%
# Import packages
import pandas as pd
import io
import requests
import pickle

# %% [markdown]
# ### Retrieve data

# %%
# get data at URL - this URL is for the state historical data, updated daily at 4pm ET
r = requests.get("https://covidtracking.com/api/v1/states/daily.csv")

# %%
# check HTTP request status
r.status_code
# Out:
# 200

# %%
# just show the first 2000 characters, the text is really long otherwise
r.text[0:2000]
# Out:
# 'date,state,positive,negative,pending,hospitalizedCurrently,hospitalizedCumulative,inIcuCurrently,inIcuCumulative,onVentilatorCurrently,onVentilatorCumulative,recovered,hash,dateChecked,death,hospitalized,total,totalTestResults,posNeg,fips,deathIncrease,hospitalizedIncrease,negativeIncrease,positiveIncrease,totalTestResultsIncrease\n20200425,AK,339,15393,,32,,,,,,217,ab748b658b14f06c13e30194100f210b2136340e,2020-04-25T20:00:00Z,9,,15732,15732,15732,02,0,0,3451,0,3451\n20200425,AL,6137,65207,,,839,,288,,170,,7bf5132c6fc6ee52a0ff04abc4cd5430c20b506c,2020-04-25T20:00:00Z,212,839,71344,71344,71344,01,15,71,18344,305,18649\n20200425,AR,2829,35224,,104,291,,,25,57,964,58b9bd7f87ceaa7eb18f988e56f5ff87f50faf84,2020-04-25T20:00:00Z,47,291,38053,38053,38053,05,2,0,2387,88,2475\n20200425,AS,0,3,17,,,,,,,,9bbbe48f731360bdff6ba5de6550e13b34e278d0,2020-04-25T20:00:00Z,0,,20,3,3,60,0,0,0,0,0\n20200425,AZ,6280,56228,,697,1022,313,,191,,1345,c61443f5a5a14bd10e15d579fdf0ff8872ddb036,2020-04-25T20:00:00Z,266,1022,62508,62508,62508,04,0,38,1559,235,1794\n20200425,CA,41137,464898,,4847,,1458,,,,,839b13775fa967aaa33b0e349cffe22cdd7ab01b,2020-04-25T20:00:00Z,1651,,506035,506035,506035,06,89,0,9979,1883,11862\n20200425,CO,12256,44533,,1084,2366,,,,,2086,cc0d38ad3c6159b86e71f9ff63a59f26eb1322d4,2020-04-25T20:00:00Z,674,2366,56789,56789,56789,08,122,129,3471,994,4465\n20200425,CT,24582,53020,,1810,,,,,,,a8ec4fc06435a938d908fb93e8ff9b97a6f1d512,2020-04-25T20:00:00Z,1862,,77602,77602,77602,09,98,0,2903,661,3564\n20200425,DC,3699,13603,,402,,120,,69,,652,dd5619154709c8564b37abff92c5afa2ec907c59,2020-04-25T20:00:00Z,165,,17302,17302,17302,11,12,0,598,171,769\n20200425,DE,3576,14122,,300,,,,,,809,ba98f1238ca631aaa590adf5e62e574a12559826,2020-04-25T20:00:00Z,112,,17698,17698,17698,10,12,0,185,134,319\n20200425,FL,30839,302260,1292,,5045,,,,,,1609ffd293a3cab3e1429599cf9acea6f18cade6,2020-04-25T20:00:00Z,1075,5045,334391,333099,333099,12,44,157,15475,665,16140\n20200425,GA,22695,96319,,,4326,,,,,,e6f8736561002b8'

# %%
# load into a Pandas dataframe
covid_df = pd.read_csv(io.StringIO(r.text)).add_prefix('o_') 

covid_df
# Out:
#         o_date o_state  o_positive  o_negative  o_pending  \
# 0     20200425      AK       339.0     15393.0        NaN
# 1     20200425      AL      6137.0     65207.0        NaN
# 2     20200425      AR      2829.0     35224.0        NaN
# 3     20200425      AS         0.0         3.0       17.0
# 4     20200425      AZ      6280.0     56228.0        NaN
# ...        ...     ...         ...         ...        ...
# 2876  20200126      WA         1.0         NaN        NaN
# 2877  20200125      WA         1.0         NaN        NaN
# 2878  20200124      WA         1.0         NaN        NaN
# 2879  20200123      WA         1.0         NaN        NaN
# 2880  20200122      WA         1.0         NaN        NaN
#
#       o_hospitalizedCurrently  o_hospitalizedCumulative  o_inIcuCurrently  \
# 0                        32.0                       NaN               NaN
# 1                         NaN                     839.0               NaN
# 2                       104.0                     291.0               NaN
# 3                         NaN                       NaN               NaN
# 4                       697.0                    1022.0             313.0
# ...                       ...                       ...               ...
# 2876                      NaN                       NaN               NaN
# 2877                      NaN                       NaN               NaN
# 2878                      NaN                       NaN               NaN
# 2879                      NaN                       NaN               NaN
# 2880                      NaN                       NaN               NaN
#
#       o_inIcuCumulative  o_onVentilatorCurrently  ...  o_hospitalized  \
# 0                   NaN                      NaN  ...             NaN
# 1                 288.0                      NaN  ...           839.0
# 2                   NaN                     25.0  ...           291.0
# 3                   NaN                      NaN  ...             NaN
# 4                   NaN                    191.0  ...          1022.0
# ...                 ...                      ...  ...             ...
# 2876                NaN                      NaN  ...             NaN
# 2877                NaN                      NaN  ...             NaN
# 2878                NaN                      NaN  ...             NaN
# 2879                NaN                      NaN  ...             NaN
# 2880                NaN                      NaN  ...             NaN
#
#       o_total o_totalTestResults o_posNeg  o_fips  o_deathIncrease  \
# 0     15732.0            15732.0  15732.0       2              0.0
# 1     71344.0            71344.0  71344.0       1             15.0
# 2     38053.0            38053.0  38053.0       5              2.0
# 3        20.0                3.0      3.0      60              0.0
# 4     62508.0            62508.0  62508.0       4              0.0
# ...       ...                ...      ...     ...              ...
# 2876      1.0                1.0      1.0      53              0.0
# 2877      1.0                1.0      1.0      53              0.0
# 2878      1.0                1.0      1.0      53              0.0
# 2879      1.0                1.0      1.0      53              0.0
# 2880      1.0                1.0      1.0      53              NaN
#
#       o_hospitalizedIncrease  o_negativeIncrease  o_positiveIncrease  \
# 0                        0.0              3451.0                 0.0
# 1                       71.0             18344.0               305.0
# 2                        0.0              2387.0                88.0
# 3                        0.0                 0.0                 0.0
# 4                       38.0              1559.0               235.0
# ...                      ...                 ...                 ...
# 2876                     0.0                 0.0                 0.0
# 2877                     0.0                 0.0                 0.0
# 2878                     0.0                 0.0                 0.0
# 2879                     0.0                 0.0                 0.0
# 2880                     NaN                 NaN                 NaN
#
#       o_totalTestResultsIncrease
# 0                         3451.0
# 1                        18649.0
# 2                         2475.0
# 3                            0.0
# 4                         1794.0
# ...                          ...
# 2876                         0.0
# 2877                         0.0
# 2878                         0.0
# 2879                         0.0
# 2880                         NaN
#
# [2881 rows x 25 columns]

# %% [markdown]
# #### You can also pull data in json format, but since they are "flat" csv loaded into Pandas is much easier to work with, but here is an example of downing a json data and loading into a Python dictionary
#
# Since the dictionary will be really large, for this example I picked the smallest json which is the US current values

# %%
r = requests.get("https://covidtracking.com/api/v1/us/current.json")

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'positive': 931698,
#   'negative': 4252937,
#   'pending': 5315,
#   'hospitalizedCurrently': 56312,
#   'hospitalizedCumulative': 94743,
#   'inIcuCurrently': 15020,
#   'inIcuCumulative': 2516,
#   'onVentilatorCurrently': 5266,
#   'onVentilatorCumulative': 227,
#   'recovered': 90445,
#   'hash': '88b95c3bf06a7da67491cd0b5e62e81489e348b6',
#   'lastModified': '2020-04-26T20:13:00.659Z',
#   'death': 47980,
#   'hospitalized': 94743,
#   'total': 5189950,
#   'totalTestResults': 5184635,
#   'posNeg': 5184635,
#   'notes': 'NOTE: "total", "posNeg", "hospitalized" will be removed in the future.'}]

# %% [markdown]
# ### Convert datatypes

# %% [markdown]
# #### Count records

# %%
# count rows and columns
covid_df.shape
# Out:
# (2881, 25)

# %% [markdown]
# #### Check and convert datatypes

# %% [markdown]
# We have:
#
# * o_date: date the cases are from; should be converted from int64 to a date object
# * o_dateChecked: date when data were validated; should be converted from string to a date object
# * o_hash: unique ID for every data update; string
# * o_state: state the cases are from; string; could be converted to category
# * o_fips: state fips code; should be converted to category; can be used to join to other datasets
# * o_positive/ negative/ pending/ hospitalizedCurrently/ inIcuCurrently/ inIcuCumulative/ onVentilatorCurrently/ onVentilatorCumulative/ recovered/ death/ hospitalized/ total: COVID-19 counts; should be converted from float to integer
# * o_totalTestResults/ posNeg: test results; posNeg is deprecated and was renamed to totalTestResults; should be converted from float to integer
# * o_deathIncrease/ hospitalized/ negative/ positive/ totalTestResults: increase in COVID-19 counts from last date; should be converted from float to integer

# %%
# check data types 
covid_df.dtypes
# Out:
# o_date                          int64
# o_state                        object
# o_positive                    float64
# o_negative                    float64
# o_pending                     float64
# o_hospitalizedCurrently       float64
# o_hospitalizedCumulative      float64
# o_inIcuCurrently              float64
# o_inIcuCumulative             float64
# o_onVentilatorCurrently       float64
# o_onVentilatorCumulative      float64
# o_recovered                   float64
# o_hash                         object
# o_dateChecked                  object
# o_death                       float64
# o_hospitalized                float64
# o_total                       float64
# o_totalTestResults            float64
# o_posNeg                      float64
# o_fips                          int64
# o_deathIncrease               float64
# o_hospitalizedIncrease        float64
# o_negativeIncrease            float64
# o_positiveIncrease            float64
# o_totalTestResultsIncrease    float64
# dtype: object

# %%
covid_df.head()
# Out:
#      o_date o_state  o_positive  o_negative  o_pending  \
# 0  20200425      AK       339.0     15393.0        NaN
# 1  20200425      AL      6137.0     65207.0        NaN
# 2  20200425      AR      2829.0     35224.0        NaN
# 3  20200425      AS         0.0         3.0       17.0
# 4  20200425      AZ      6280.0     56228.0        NaN
#
#    o_hospitalizedCurrently  o_hospitalizedCumulative  o_inIcuCurrently  \
# 0                     32.0                       NaN               NaN
# 1                      NaN                     839.0               NaN
# 2                    104.0                     291.0               NaN
# 3                      NaN                       NaN               NaN
# 4                    697.0                    1022.0             313.0
#
#    o_inIcuCumulative  o_onVentilatorCurrently  ...  o_hospitalized  o_total  \
# 0                NaN                      NaN  ...             NaN  15732.0
# 1              288.0                      NaN  ...           839.0  71344.0
# 2                NaN                     25.0  ...           291.0  38053.0
# 3                NaN                      NaN  ...             NaN     20.0
# 4                NaN                    191.0  ...          1022.0  62508.0
#
#   o_totalTestResults o_posNeg  o_fips  o_deathIncrease  \
# 0            15732.0  15732.0       2              0.0
# 1            71344.0  71344.0       1             15.0
# 2            38053.0  38053.0       5              2.0
# 3                3.0      3.0      60              0.0
# 4            62508.0  62508.0       4              0.0
#
#    o_hospitalizedIncrease  o_negativeIncrease  o_positiveIncrease  \
# 0                     0.0              3451.0                 0.0
# 1                    71.0             18344.0               305.0
# 2                     0.0              2387.0                88.0
# 3                     0.0                 0.0                 0.0
# 4                    38.0              1559.0               235.0
#
#    o_totalTestResultsIncrease
# 0                      3451.0
# 1                     18649.0
# 2                      2475.0
# 3                         0.0
# 4                      1794.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ##### String --> Date columns

# %%
# create new version of column as a datetime object - with ymd
covid_df["date"] = pd.to_datetime(covid_df["o_date"], format='%Y%m%d')

# create new version of column as a datetime object - with ymdhms
covid_df["dateChecked"] = pd.to_datetime(covid_df["o_dateChecked"])
# check conversion 
covid_df[["o_date", "date", "o_dateChecked", "dateChecked"]].head()
# Out:
#      o_date       date         o_dateChecked               dateChecked
# 0  20200425 2020-04-25  2020-04-25T20:00:00Z 2020-04-25 20:00:00+00:00
# 1  20200425 2020-04-25  2020-04-25T20:00:00Z 2020-04-25 20:00:00+00:00
# 2  20200425 2020-04-25  2020-04-25T20:00:00Z 2020-04-25 20:00:00+00:00
# 3  20200425 2020-04-25  2020-04-25T20:00:00Z 2020-04-25 20:00:00+00:00
# 4  20200425 2020-04-25  2020-04-25T20:00:00Z 2020-04-25 20:00:00+00:00

# %% [markdown]
# ##### String --> Categorical columns

# %%
# identify which columns to convert 
str_to_category = ["o_state", "o_fips"]
# create new column names
str_to_category_new = list(map(lambda x: x.replace('o_', ''), str_to_category))
# add new converted columns
covid_df[str_to_category_new] = covid_df[str_to_category].apply(lambda x: x.astype('category'))
# check conversion
covid_df[str_to_category + str_to_category_new]
# Out:
#      o_state  o_fips state fips
# 0         AK       2    AK    2
# 1         AL       1    AL    1
# 2         AR       5    AR    5
# 3         AS      60    AS   60
# 4         AZ       4    AZ    4
# ...      ...     ...   ...  ...
# 2876      WA      53    WA   53
# 2877      WA      53    WA   53
# 2878      WA      53    WA   53
# 2879      WA      53    WA   53
# 2880      WA      53    WA   53
#
# [2881 rows x 4 columns]

# %%
# check conversion
covid_df[str_to_category + str_to_category_new].dtypes
# Out:
# o_state      object
# o_fips        int64
# state      category
# fips       category
# dtype: object

# %% [markdown]
# ##### Float --> Integer columns

# %%
# identify which columns to convert 
to_int = list(covid_df.select_dtypes(include = ["float64"]).columns)
# create new column names
converted_to_int = list(map(lambda x: x.replace('o_', ''), to_int))
# add new converted columns
covid_df[converted_to_int] = covid_df[to_int].apply(lambda x: x.astype('Int64'))
# check conversion
covid_df[to_int].head()
# Out:
#    o_positive  o_negative  o_pending  o_hospitalizedCurrently  \
# 0       339.0     15393.0        NaN                     32.0
# 1      6137.0     65207.0        NaN                      NaN
# 2      2829.0     35224.0        NaN                    104.0
# 3         0.0         3.0       17.0                      NaN
# 4      6280.0     56228.0        NaN                    697.0
#
#    o_hospitalizedCumulative  o_inIcuCurrently  o_inIcuCumulative  \
# 0                       NaN               NaN                NaN
# 1                     839.0               NaN              288.0
# 2                     291.0               NaN                NaN
# 3                       NaN               NaN                NaN
# 4                    1022.0             313.0                NaN
#
#    o_onVentilatorCurrently  o_onVentilatorCumulative  o_recovered  o_death  \
# 0                      NaN                       NaN        217.0      9.0
# 1                      NaN                     170.0          NaN    212.0
# 2                     25.0                      57.0        964.0     47.0
# 3                      NaN                       NaN          NaN      0.0
# 4                    191.0                       NaN       1345.0    266.0
#
#    o_hospitalized  o_total  o_totalTestResults  o_posNeg  o_deathIncrease  \
# 0             NaN  15732.0             15732.0   15732.0              0.0
# 1           839.0  71344.0             71344.0   71344.0             15.0
# 2           291.0  38053.0             38053.0   38053.0              2.0
# 3             NaN     20.0                 3.0       3.0              0.0
# 4          1022.0  62508.0             62508.0   62508.0              0.0
#
#    o_hospitalizedIncrease  o_negativeIncrease  o_positiveIncrease  \
# 0                     0.0              3451.0                 0.0
# 1                    71.0             18344.0               305.0
# 2                     0.0              2387.0                88.0
# 3                     0.0                 0.0                 0.0
# 4                    38.0              1559.0               235.0
#
#    o_totalTestResultsIncrease
# 0                      3451.0
# 1                     18649.0
# 2                      2475.0
# 3                         0.0
# 4                      1794.0

# %%
# check conversion
covid_df[converted_to_int].head()
# Out:
#    positive  negative  pending  hospitalizedCurrently  hospitalizedCumulative  \
# 0       339     15393      NaN                     32                     NaN
# 1      6137     65207      NaN                    NaN                     839
# 2      2829     35224      NaN                    104                     291
# 3         0         3       17                    NaN                     NaN
# 4      6280     56228      NaN                    697                    1022
#
#    inIcuCurrently  inIcuCumulative  onVentilatorCurrently  \
# 0             NaN              NaN                    NaN
# 1             NaN              288                    NaN
# 2             NaN              NaN                     25
# 3             NaN              NaN                    NaN
# 4             313              NaN                    191
#
#    onVentilatorCumulative  recovered  death  hospitalized  total  \
# 0                     NaN        217      9           NaN  15732
# 1                     170        NaN    212           839  71344
# 2                      57        964     47           291  38053
# 3                     NaN        NaN      0           NaN     20
# 4                     NaN       1345    266          1022  62508
#
#    totalTestResults  posNeg  deathIncrease  hospitalizedIncrease  \
# 0             15732   15732              0                     0
# 1             71344   71344             15                    71
# 2             38053   38053              2                     0
# 3                 3       3              0                     0
# 4             62508   62508              0                    38
#
#    negativeIncrease  positiveIncrease  totalTestResultsIncrease
# 0              3451                 0                      3451
# 1             18344               305                     18649
# 2              2387                88                      2475
# 3                 0                 0                         0
# 4              1559               235                      1794

# %%
# check conversion
covid_df[to_int + converted_to_int].dtypes
# Out:
# o_positive                    float64
# o_negative                    float64
# o_pending                     float64
# o_hospitalizedCurrently       float64
# o_hospitalizedCumulative      float64
# o_inIcuCurrently              float64
# o_inIcuCumulative             float64
# o_onVentilatorCurrently       float64
# o_onVentilatorCumulative      float64
# o_recovered                   float64
# o_death                       float64
# o_hospitalized                float64
# o_total                       float64
# o_totalTestResults            float64
# o_posNeg                      float64
# o_deathIncrease               float64
# o_hospitalizedIncrease        float64
# o_negativeIncrease            float64
# o_positiveIncrease            float64
# o_totalTestResultsIncrease    float64
# positive                        Int64
# negative                        Int64
# pending                         Int64
# hospitalizedCurrently           Int64
# hospitalizedCumulative          Int64
# inIcuCurrently                  Int64
# inIcuCumulative                 Int64
# onVentilatorCurrently           Int64
# onVentilatorCumulative          Int64
# recovered                       Int64
# death                           Int64
# hospitalized                    Int64
# total                           Int64
# totalTestResults                Int64
# posNeg                          Int64
# deathIncrease                   Int64
# hospitalizedIncrease            Int64
# negativeIncrease                Int64
# positiveIncrease                Int64
# totalTestResultsIncrease        Int64
# dtype: object

# %% [markdown]
# ### Check missingness

# %% [markdown]
# We have a lot of missing data in the coumns that track COVID related things. However, we don't have any missing data in the ID columns (date, state, fips). Given the difficulty with retrieving these data [https://covidtracking.com/data](- as documented on the COVID Tracking Project website -) one would expect at least some missing data in these columns.
#
# These missingness counts are a further validation that the datatype conversions did not introduce additional NAs.

# %%
covid_df.isnull().sum(axis = 0)
# Out:
# o_date                           0
# o_state                          0
# o_positive                      15
# o_negative                     193
# o_pending                     2256
# o_hospitalizedCurrently       2019
# o_hospitalizedCumulative      1896
# o_inIcuCurrently              2451
# o_inIcuCumulative             2709
# o_onVentilatorCurrently       2541
# o_onVentilatorCumulative      2828
# o_recovered                   2137
# o_hash                           0
# o_dateChecked                    0
# o_death                        739
# o_hospitalized                1896
# o_total                          2
# o_totalTestResults               2
# o_posNeg                         2
# o_fips                           0
# o_deathIncrease                 56
# o_hospitalizedIncrease          56
# o_negativeIncrease              56
# o_positiveIncrease              56
# o_totalTestResultsIncrease      56
# date                             0
# dateChecked                      0
# state                            0
# fips                             0
# positive                        15
# negative                       193
# pending                       2256
# hospitalizedCurrently         2019
# hospitalizedCumulative        1896
# inIcuCurrently                2451
# inIcuCumulative               2709
# onVentilatorCurrently         2541
# onVentilatorCumulative        2828
# recovered                     2137
# death                          739
# hospitalized                  1896
# total                            2
# totalTestResults                 2
# posNeg                           2
# deathIncrease                   56
# hospitalizedIncrease            56
# negativeIncrease                56
# positiveIncrease                56
# totalTestResultsIncrease        56
# dtype: int64

# %% [markdown]
# ### Generate summary statistics

# %% [markdown]
# The summary statistics of original and converted columns are another method for validating the column type conversion. We can see that the conversion did not appear to change summary statistics of the data so from now on we will use the converted columns.

# %%
# display summary statistics of original columns
covid_df[covid_df.columns[pd.Series(covid_df.columns).str.startswith('o_')]].describe(include = 'all')
# Out:
#               o_date o_state     o_positive     o_negative     o_pending  \
# count   2.881000e+03    2881    2866.000000    2688.000000    625.000000
# unique           NaN      56            NaN            NaN           NaN
# top              NaN      WA            NaN            NaN           NaN
# freq             NaN      95            NaN            NaN           NaN
# mean    2.020036e+07     NaN    5390.375436   24698.565104   1512.348800
# std     5.178699e+01     NaN   20434.225767   48083.576590   7667.013322
# min     2.020012e+07     NaN       0.000000       0.000000      0.000000
# 25%     2.020032e+07     NaN      32.250000     420.750000      6.000000
# 50%     2.020033e+07     NaN     476.000000    7504.500000     32.000000
# 75%     2.020041e+07     NaN    2883.250000   28201.000000    236.000000
# max     2.020042e+07     NaN  282143.000000  495425.000000  64400.000000
#
#         o_hospitalizedCurrently  o_hospitalizedCumulative  o_inIcuCurrently  \
# count                862.000000                985.000000        430.000000
# unique                      NaN                       NaN               NaN
# top                         NaN                       NaN               NaN
# freq                        NaN                       NaN               NaN
# mean                1466.431555               1711.577665        720.813953
# std                 3100.638022               7001.974126       1157.295186
# min                    2.000000                  0.000000          2.000000
# 25%                   74.250000                 57.000000         74.000000
# 50%                  295.000000                241.000000        162.500000
# 75%                 1410.500000                760.000000       1047.500000
# max                18825.000000              57103.000000       5225.000000
#
#         o_inIcuCumulative  o_onVentilatorCurrently  ...  o_hospitalized  \
# count          172.000000               340.000000  ...      985.000000
# unique                NaN                      NaN  ...             NaN
# top                   NaN                      NaN  ...             NaN
# freq                  NaN                      NaN  ...             NaN
# mean           225.127907               336.652941  ...     1711.577665
# std            222.239205               445.080255  ...     7001.974126
# min              6.000000                 2.000000  ...        0.000000
# 25%             43.000000                26.000000  ...       57.000000
# 50%            176.000000                81.500000  ...      241.000000
# 75%            290.250000               507.000000  ...      760.000000
# max            938.000000              1705.000000  ...    57103.000000
#
#               o_total o_totalTestResults       o_posNeg       o_fips  \
# count     2879.000000        2879.000000    2879.000000  2881.000000
# unique            NaN                NaN            NaN          NaN
# top               NaN                NaN            NaN          NaN
# freq              NaN                NaN            NaN          NaN
# mean     28754.351164       28426.036471   28426.036471    32.201666
# std      64138.249628       63862.788101   63862.788101    18.417664
# min          0.000000           0.000000       0.000000     1.000000
# 25%        292.000000         264.500000     264.500000    17.000000
# 50%       6674.000000        6633.000000    6633.000000    32.000000
# 75%      29316.500000       29109.000000   29109.000000    46.000000
# max     777568.000000      777568.000000  777568.000000    78.000000
#
#         o_deathIncrease  o_hospitalizedIncrease  o_negativeIncrease  \
# count       2825.000000             2825.000000         2825.000000
# unique              NaN                     NaN                 NaN
# top                 NaN                     NaN                 NaN
# freq                NaN                     NaN                 NaN
# mean          16.984071               35.247788         1505.098761
# std           66.684907              235.416836         4360.269069
# min         -201.000000             -655.000000        -5086.000000
# 25%            0.000000                0.000000            9.000000
# 50%            1.000000                0.000000          394.000000
# 75%            7.000000                3.000000         1563.000000
# max          799.000000             4493.000000       163092.000000
#
#         o_positiveIncrease  o_totalTestResultsIncrease
# count          2825.000000                 2825.000000
# unique                 NaN                         NaN
# top                    NaN                         NaN
# freq                   NaN                         NaN
# mean            329.766372                 1834.865133
# std            1004.373163                 4888.489829
# min            -383.000000                -4714.000000
# 25%               5.000000                   32.000000
# 50%              48.000000                  467.000000
# 75%             225.000000                 1851.000000
# max           11571.000000               165227.000000
#
# [11 rows x 25 columns]

# %%
# extract converted columns & unconverted hash column
converted_covid_df = covid_df[list(
    map(lambda x: x.replace('o_', '') if x != 'o_hash' else x, 
        list(covid_df[covid_df.columns[pd.Series(covid_df.columns).str.startswith('o_')]].columns)))]
         
# show summary statistics
converted_covid_df.describe(include = 'all')
# Out:
#                        date state       positive       negative       pending  \
# count                  2881  2881    2866.000000    2688.000000    625.000000
# unique                   95    56            NaN            NaN           NaN
# top     2020-03-16 00:00:00    WA            NaN            NaN           NaN
# freq                     56    95            NaN            NaN           NaN
# first   2020-01-22 00:00:00   NaN            NaN            NaN           NaN
# last    2020-04-25 00:00:00   NaN            NaN            NaN           NaN
# mean                    NaN   NaN    5390.375436   24698.565104   1512.348800
# std                     NaN   NaN   20434.225767   48083.576590   7667.013322
# min                     NaN   NaN       0.000000       0.000000      0.000000
# 25%                     NaN   NaN      32.250000     420.750000      6.000000
# 50%                     NaN   NaN     476.000000    7504.500000     32.000000
# 75%                     NaN   NaN    2883.250000   28201.000000    236.000000
# max                     NaN   NaN  282143.000000  495425.000000  64400.000000
#
#         hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count              862.000000              985.000000      430.000000
# unique                    NaN                     NaN             NaN
# top                       NaN                     NaN             NaN
# freq                      NaN                     NaN             NaN
# first                     NaN                     NaN             NaN
# last                      NaN                     NaN             NaN
# mean              1466.431555             1711.577665      720.813953
# std               3100.638022             7001.974126     1157.295186
# min                  2.000000                0.000000        2.000000
# 25%                 74.250000               57.000000       74.000000
# 50%                295.000000              241.000000      162.500000
# 75%               1410.500000              760.000000     1047.500000
# max              18825.000000            57103.000000     5225.000000
#
#         inIcuCumulative  onVentilatorCurrently  ...  hospitalized  \
# count        172.000000             340.000000  ...    985.000000
# unique              NaN                    NaN  ...           NaN
# top                 NaN                    NaN  ...           NaN
# freq                NaN                    NaN  ...           NaN
# first               NaN                    NaN  ...           NaN
# last                NaN                    NaN  ...           NaN
# mean         225.127907             336.652941  ...   1711.577665
# std          222.239205             445.080255  ...   7001.974126
# min            6.000000               2.000000  ...      0.000000
# 25%           43.000000              26.000000  ...     57.000000
# 50%          176.000000              81.500000  ...    241.000000
# 75%          290.250000             507.000000  ...    760.000000
# max          938.000000            1705.000000  ...  57103.000000
#
#                 total totalTestResults         posNeg    fips  deathIncrease  \
# count     2879.000000      2879.000000    2879.000000  2881.0    2825.000000
# unique            NaN              NaN            NaN    56.0            NaN
# top               NaN              NaN            NaN    53.0            NaN
# freq              NaN              NaN            NaN    95.0            NaN
# first             NaN              NaN            NaN     NaN            NaN
# last              NaN              NaN            NaN     NaN            NaN
# mean     28754.351164     28426.036471   28426.036471     NaN      16.984071
# std      64138.249628     63862.788101   63862.788101     NaN      66.684907
# min          0.000000         0.000000       0.000000     NaN    -201.000000
# 25%        292.000000       264.500000     264.500000     NaN       0.000000
# 50%       6674.000000      6633.000000    6633.000000     NaN       1.000000
# 75%      29316.500000     29109.000000   29109.000000     NaN       7.000000
# max     777568.000000    777568.000000  777568.000000     NaN     799.000000
#
#         hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# count            2825.000000       2825.000000       2825.000000
# unique                   NaN               NaN               NaN
# top                      NaN               NaN               NaN
# freq                     NaN               NaN               NaN
# first                    NaN               NaN               NaN
# last                     NaN               NaN               NaN
# mean               35.247788       1505.098761        329.766372
# std               235.416836       4360.269069       1004.373163
# min              -655.000000      -5086.000000       -383.000000
# 25%                 0.000000          9.000000          5.000000
# 50%                 0.000000        394.000000         48.000000
# 75%                 3.000000       1563.000000        225.000000
# max              4493.000000     163092.000000      11571.000000
#
#         totalTestResultsIncrease
# count                2825.000000
# unique                       NaN
# top                          NaN
# freq                         NaN
# first                        NaN
# last                         NaN
# mean                 1834.865133
# std                  4888.489829
# min                 -4714.000000
# 25%                    32.000000
# 50%                   467.000000
# 75%                  1851.000000
# max                165227.000000
#
# [13 rows x 25 columns]

# %% [markdown]
# #### Check duplicates

# %% [markdown]
# There are no perfectly duplicated rows.

# %%
sum(converted_covid_df.duplicated())
# Out:
# 0

# %% [markdown]
# There are no duplications for the primary keys - as expected, there appears to be one column for every day, for every state (whether identified via state name or fips code).

# %%
# check duplication w/ date and state name
converted_covid_df[converted_covid_df.duplicated(subset=['date','state'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [date, state, positive, negative, pending, hospitalizedCurrently, hospitalizedCumulative, inIcuCurrently, inIcuCumulative, onVentilatorCurrently, onVentilatorCumulative, recovered, o_hash, dateChecked, death, hospitalized, total, totalTestResults, posNeg, fips, deathIncrease, hospitalizedIncrease, negativeIncrease, positiveIncrease, totalTestResultsIncrease]
# Index: []
#
# [0 rows x 25 columns]

# %%
# check duplication w/ date and state fips code
converted_covid_df[converted_covid_df.duplicated(subset=['date','fips'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [date, state, positive, negative, pending, hospitalizedCurrently, hospitalizedCumulative, inIcuCurrently, inIcuCumulative, onVentilatorCurrently, onVentilatorCumulative, recovered, o_hash, dateChecked, death, hospitalized, total, totalTestResults, posNeg, fips, deathIncrease, hospitalizedIncrease, negativeIncrease, positiveIncrease, totalTestResultsIncrease]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# #### Recount records

# %%
# count rows 
covid_df.shape[0] == converted_covid_df.shape[0]
# Out:
# True

# %% [markdown]
# ### Pickle data

# %%
pickle.dump(converted_covid_df, open( "../Data_pkl/covid19/covidtrackingproject_df.pkl", "wb" ) )
