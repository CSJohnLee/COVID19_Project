# %% [markdown]
# # COVID-19 MIDS Collaboration
#
# ## Data Import
#
# This Jupyter Notebook reads in raw data as csv files and exports them as [pickle files for faster loading](https://medium.com/better-programming/load-fast-load-big-with-compressed-pickles-5f311584507e).

# %% [markdown]
# ### Data sources
#
# State and county FIPS codes: https://github.com/kjhealy/fips-codes

# %% [markdown]
# ### Set up environment

# %%
# Import packages
import pandas as pd # to read in csv
import numpy as np # to process data
import pickle # to pickle files

# %% [markdown]
# Here, we import all of our datasets into a pandas dataframe and add a "o_" prefix to all columsn to demarcate which columns were the originals.

# %%
#Read in data & add "o_" prefix to demarcate which columns were the originals 
# state fips codes and names 
state_fips_df = pd.read_csv("../Data_raw/fips-codes/state_fips_master.csv").add_prefix('o_')
# state and county fips codes and names 
fips_df = pd.read_csv("../Data_raw/fips-codes/county_fips_master.csv", encoding='cp1252').add_prefix('o_')

# %% [markdown]
# ### Inspect data

# %% [markdown]
# #### State & County FIPS codes and names

# %% [markdown]
# Our dataset tracking state and county FIPS codes has 50 rows and 10 columns. There is one row for each of the 50 states - we probably would want to merge the above file on this one to obtain the correct state FIPS codes and limit our data to only these 50 states for easier comparison.

# %%
# display rows & columns
state_fips_df.shape
# Out:
# (50, 10)

# %% [markdown]
# We have:
#
# * 5 string columns tracking the county name, abbreviation, region, and division
# * 5 integer columns tracking fips codes and tracking identifiers we can use to match to the county file
#     * These should be converted to categories

# %%
# show data types 
state_fips_df.dtypes
# Out:
# o_state_name       object
# o_state_abbr       object
# o_long_name        object
# o_fips              int64
# o_sumlev            int64
# o_region            int64
# o_division          int64
# o_state             int64
# o_region_name      object
# o_division_name    object
# dtype: object

# %%
# visual inspection
state_fips_df.head()
# Out:
#   o_state_name o_state_abbr    o_long_name  o_fips  o_sumlev  o_region  \
# 0      Alabama           AL     Alabama AL       1        40         3
# 1       Alaska           AK      Alaska AK       2        40         4
# 2      Arizona           AZ     Arizona AZ       4        40         4
# 3     Arkansas           AR    Arkansas AR       5        40         3
# 4   California           CA  California CA       6        40         4
#
#    o_division  o_state o_region_name     o_division_name
# 0           6        1         South  East South Central
# 1           9        2          West             Pacific
# 2           8        4          West            Mountain
# 3           7        5         South  West South Central
# 4           9        6          West             Pacific

# %% [markdown]
# #### Check and convert datatypes

# %%
# convert floats to categories
state_fips_df["state_fips"] = state_fips_df["o_state"].astype('category')
state_fips_df["fips"] = state_fips_df["o_fips"].astype('category')
state_fips_df["region"] = state_fips_df["o_region"].astype('category')
state_fips_df["division"] = state_fips_df["o_division"].astype('category')
state_fips_df["sumlev"] = state_fips_df["o_sumlev"].astype('category')

# %%
# visual check of column conversions - these worked 
state_fips_df.head()
# Out:
#   o_state_name o_state_abbr    o_long_name  o_fips  o_sumlev  o_region  \
# 0      Alabama           AL     Alabama AL       1        40         3
# 1       Alaska           AK      Alaska AK       2        40         4
# 2      Arizona           AZ     Arizona AZ       4        40         4
# 3     Arkansas           AR    Arkansas AR       5        40         3
# 4   California           CA  California CA       6        40         4
#
#    o_division  o_state o_region_name     o_division_name state_fips fips  \
# 0           6        1         South  East South Central          1    1
# 1           9        2          West             Pacific          2    2
# 2           8        4          West            Mountain          4    4
# 3           7        5         South  West South Central          5    5
# 4           9        6          West             Pacific          6    6
#
#   region division sumlev
# 0      3        6     40
# 1      4        9     40
# 2      4        8     40
# 3      3        7     40
# 4      4        9     40

# %% [markdown]
# #### Generate summary statistics

# %% [markdown]
# State FIPS codes range from 1-56. Since there are 50 states in the data, this means that some numbers in this range do not represent FIPS codes. Region IDs range from 1-4. Division names range from 1-9. The o_sumlev column is a constant and is likely not needed.
#
# We can see that we have 50 states as expected. These are divided into 4 regions and 9 divisions.

# %%
# display summary statistics
state_fips_df.describe(include = 'all')
# Out:
#        o_state_name o_state_abbr      o_long_name     o_fips  o_sumlev  \
# count            50           50               50  50.000000      50.0
# unique           50           50               50        NaN       NaN
# top         Georgia           RI  Pennsylvania PA        NaN       NaN
# freq              1            1                1        NaN       NaN
# mean            NaN          NaN              NaN  29.320000      40.0
# std             NaN          NaN              NaN  15.782243       0.0
# min             NaN          NaN              NaN   1.000000      40.0
# 25%             NaN          NaN              NaN  17.250000      40.0
# 50%             NaN          NaN              NaN  29.500000      40.0
# 75%             NaN          NaN              NaN  41.750000      40.0
# max             NaN          NaN              NaN  56.000000      40.0
#
#          o_region  o_division    o_state o_region_name o_division_name  \
# count   50.000000   50.000000  50.000000            50              50
# unique        NaN         NaN        NaN             4               9
# top           NaN         NaN        NaN         South        Mountain
# freq          NaN         NaN        NaN            16               8
# mean     2.660000    5.120000  29.320000           NaN             NaN
# std      1.061574    2.560612  15.782243           NaN             NaN
# min      1.000000    1.000000   1.000000           NaN             NaN
# 25%      2.000000    3.000000  17.250000           NaN             NaN
# 50%      3.000000    5.000000  29.500000           NaN             NaN
# 75%      3.750000    7.750000  41.750000           NaN             NaN
# max      4.000000    9.000000  56.000000           NaN             NaN
#
#         state_fips  fips  region  division  sumlev
# count         50.0  50.0    50.0      50.0    50.0
# unique        50.0  50.0     4.0       9.0     1.0
# top           56.0  56.0     3.0       8.0    40.0
# freq           1.0   1.0    16.0       8.0    50.0
# mean           NaN   NaN     NaN       NaN     NaN
# std            NaN   NaN     NaN       NaN     NaN
# min            NaN   NaN     NaN       NaN     NaN
# 25%            NaN   NaN     NaN       NaN     NaN
# 50%            NaN   NaN     NaN       NaN     NaN
# 75%            NaN   NaN     NaN       NaN     NaN
# max            NaN   NaN     NaN       NaN     NaN

# %% [markdown]
# #### Check missingness

# %% [markdown]
# There is no missing data.

# %%
state_fips_df.isnull().sum(axis = 0)
# Out:
# o_state_name       0
# o_state_abbr       0
# o_long_name        0
# o_fips             0
# o_sumlev           0
# o_region           0
# o_division         0
# o_state            0
# o_region_name      0
# o_division_name    0
# state_fips         0
# fips               0
# region             0
# division           0
# sumlev             0
# dtype: int64

# %% [markdown]
# #### Check duplicates

# %% [markdown]
# There are no perfectly duplicated rows.

# %%
sum(state_fips_df.duplicated())
# Out:
# 0

# %% [markdown]
# This dataset is at the state level (50 rows for 50 unique states).

# %% [markdown]
# #### State & County FIPS codes and names

# %% [markdown]
# Our dataset tracking state and county FIPS codes has 3,146 rows and 13 columns.

# %%
# display rows & columns
fips_df.shape
# Out:
# (3146, 13)

# %% [markdown]
# We have:
#
# * 6 string columns tracking the county and state name, abbreviation, region, and division
# * 1 integer column tracking fips codes
# * 4 float columns tracking identifiers we can use to match to the county file (these need to be converted to integers)
# * 1 string column that stores an additional format of the integer columns that can be used for matching

# %%
# show data types
fips_df.dtypes
# Out:
# o_fips               int64
# o_county_name       object
# o_state_abbr        object
# o_state_name        object
# o_long_name         object
# o_sumlev           float64
# o_region           float64
# o_division         float64
# o_state            float64
# o_county           float64
# o_crosswalk         object
# o_region_name       object
# o_division_name     object
# dtype: object

# %% [markdown]
# Since FIPS codes are stored as integers, we can see that we lose the leading zeros. This is something to be careful with when it comes to matching. These are already split into state and county FIPS codes in the o_state and o_county columns. We could add the county name and FIPS codes to the merged file with COVID-19 and state data. The match would not be perfect given the issues we saw in the COVID-19 data.

# %%
# visual inspection
fips_df.head()
# Out:
#    o_fips   o_county_name o_state_abbr o_state_name        o_long_name  \
# 0    1001  Autauga County           AL      Alabama  Autauga County AL
# 1    1003  Baldwin County           AL      Alabama  Baldwin County AL
# 2    1005  Barbour County           AL      Alabama  Barbour County AL
# 3    1007     Bibb County           AL      Alabama     Bibb County AL
# 4    1009   Blount County           AL      Alabama   Blount County AL
#
#    o_sumlev  o_region  o_division  o_state  o_county o_crosswalk  \
# 0      50.0       3.0         6.0      1.0       1.0     3-6-1-1
# 1      50.0       3.0         6.0      1.0       3.0     3-6-1-3
# 2      50.0       3.0         6.0      1.0       5.0     3-6-1-5
# 3      50.0       3.0         6.0      1.0       7.0     3-6-1-7
# 4      50.0       3.0         6.0      1.0       9.0     3-6-1-9
#
#   o_region_name     o_division_name
# 0         South  East South Central
# 1         South  East South Central
# 2         South  East South Central
# 3         South  East South Central
# 4         South  East South Central

# %% [markdown]
# #### Check and convert datatypes

# %%
# convert floats to categories
fips_df["state_fips"] = fips_df["o_state"].astype('category')
fips_df["county_fips"] = fips_df["o_county"].astype('category')
fips_df["region"] = fips_df["o_region"].astype('category')
fips_df["division"] = fips_df["o_division"].astype('category')
fips_df["sumlev"] = fips_df["o_sumlev"].astype('category')

# %%
# visual check of column conversions - these worked 
fips_df.head()
# Out:
#    o_fips   o_county_name o_state_abbr o_state_name        o_long_name  \
# 0    1001  Autauga County           AL      Alabama  Autauga County AL
# 1    1003  Baldwin County           AL      Alabama  Baldwin County AL
# 2    1005  Barbour County           AL      Alabama  Barbour County AL
# 3    1007     Bibb County           AL      Alabama     Bibb County AL
# 4    1009   Blount County           AL      Alabama   Blount County AL
#
#    o_sumlev  o_region  o_division  o_state  o_county o_crosswalk  \
# 0      50.0       3.0         6.0      1.0       1.0     3-6-1-1
# 1      50.0       3.0         6.0      1.0       3.0     3-6-1-3
# 2      50.0       3.0         6.0      1.0       5.0     3-6-1-5
# 3      50.0       3.0         6.0      1.0       7.0     3-6-1-7
# 4      50.0       3.0         6.0      1.0       9.0     3-6-1-9
#
#   o_region_name     o_division_name state_fips county_fips region division  \
# 0         South  East South Central        1.0         1.0    3.0      6.0
# 1         South  East South Central        1.0         3.0    3.0      6.0
# 2         South  East South Central        1.0         5.0    3.0      6.0
# 3         South  East South Central        1.0         7.0    3.0      6.0
# 4         South  East South Central        1.0         9.0    3.0      6.0
#
#   sumlev
# 0   50.0
# 1   50.0
# 2   50.0
# 3   50.0
# 4   50.0

# %% [markdown]
# #### Generate summary statistics

# %% [markdown]
# State FIPS codes range from 1-56, as expected. The county FIPS codes range from 0-840. Region IDs range from 1-4 and division names from 1-9, as expected. The o_sumlev column is not a constant - it seems to take the value of either 40 or 50 (but that 40 is rare). We are missing some sumlev, regions, divisions and state & county FIPS codes.
#
# We can see that we have 51 states - 1 more than expected. These are divided into 4 regions and 9 divisions.

# %%
# display numerical data summary statistics
fips_df.describe(include = 'all')
# Out:
#               o_fips      o_county_name o_state_abbr o_state_name  \
# count    3146.000000               3146         3146         3146
# unique           NaN               1879           51           51
# top              NaN  Washington County           TX        Texas
# freq             NaN                 30          254          254
# mean    30380.268595                NaN          NaN          NaN
# std     15172.365155                NaN          NaN          NaN
# min      1001.000000                NaN          NaN          NaN
# 25%     18175.500000                NaN          NaN          NaN
# 50%     29176.000000                NaN          NaN          NaN
# 75%     45082.500000                NaN          NaN          NaN
# max     56045.000000                NaN          NaN          NaN
#
#                     o_long_name     o_sumlev     o_region   o_division  \
# count                      3146  3143.000000  3143.000000  3143.000000
# unique                     3145          NaN          NaN          NaN
# top     District of Columbia DC          NaN          NaN          NaN
# freq                          2          NaN          NaN          NaN
# mean                        NaN    49.996818     2.668788     5.192491
# std                         NaN     0.178372     0.803043     1.963750
# min                         NaN    40.000000     1.000000     1.000000
# 25%                         NaN    50.000000     2.000000     4.000000
# 50%                         NaN    50.000000     3.000000     5.000000
# 75%                         NaN    50.000000     3.000000     7.000000
# max                         NaN    50.000000     4.000000     9.000000
#
#             o_state     o_county  o_crosswalk o_region_name  \
# count   3143.000000  3143.000000         3146          3143
# unique          NaN          NaN         3144             4
# top             NaN          NaN  NA-NA-NA-NA         South
# freq            NaN          NaN            3          1423
# mean      30.273942   103.539930          NaN           NaN
# std       15.145834   107.702765          NaN           NaN
# min        1.000000     0.000000          NaN           NaN
# 25%       18.000000    35.000000          NaN           NaN
# 50%       29.000000    79.000000          NaN           NaN
# 75%       45.000000   133.000000          NaN           NaN
# max       56.000000   840.000000          NaN           NaN
#
#            o_division_name  state_fips  county_fips  region  division  sumlev
# count                 3143      3143.0       3143.0  3143.0    3143.0  3143.0
# unique                   9        51.0        325.0     4.0       9.0     2.0
# top     West North Central        48.0          1.0     3.0       4.0    50.0
# freq                   618       254.0         49.0  1423.0     618.0  3142.0
# mean                   NaN         NaN          NaN     NaN       NaN     NaN
# std                    NaN         NaN          NaN     NaN       NaN     NaN
# min                    NaN         NaN          NaN     NaN       NaN     NaN
# 25%                    NaN         NaN          NaN     NaN       NaN     NaN
# 50%                    NaN         NaN          NaN     NaN       NaN     NaN
# 75%                    NaN         NaN          NaN     NaN       NaN     NaN
# max                    NaN         NaN          NaN     NaN       NaN     NaN

# %% [markdown]
# The 1 extra state in the county dataset is Washington, D.C.

# %%
fips_df["o_state_name"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# The additional state FIPS is for Washington, D.C.

# %%
state_fips_df["o_state_name"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %% [markdown]
# Washington, D.C. also accounts for the discrepancy in the o_sumlev column.

# %%
fips_df["o_state_name"][fips_df["o_sumlev"] == 40]
# Out:
# 320    District of Columbia
# Name: o_state_name, dtype: object

# %% [markdown]
# #### Check missing data

# %% [markdown]
# We are missing some sumlev, regions, divisions and state & county FIPS codes.

# %%
fips_df.isnull().sum(axis = 0)
# Out:
# o_fips             0
# o_county_name      0
# o_state_abbr       0
# o_state_name       0
# o_long_name        0
# o_sumlev           3
# o_region           3
# o_division         3
# o_state            3
# o_county           3
# o_crosswalk        0
# o_region_name      3
# o_division_name    3
# state_fips         3
# county_fips        3
# region             3
# division           3
# sumlev             3
# dtype: int64

# %% [markdown]
# It is unclear why these 3 rows are missing these values. This may pose an issue, unless these counties are not usually used in datasets for some reason (perhaps they are not very populated). One appears to be a city (Bedford City, VA). We can retain these for now and drop them later.

# %%
fips_df[fips_df['county_fips'].isnull()]
# Out:
#       o_fips             o_county_name o_state_abbr  o_state_name  \
# 93      2270  Wade Hampton Census Area           AK        Alaska
# 2420   46113            Shannon County           SD  South Dakota
# 2919   51515              Bedford city           VA      Virginia
#
#                       o_long_name  o_sumlev  o_region  o_division  o_state  \
# 93    Wade Hampton Census Area AK       NaN       NaN         NaN      NaN
# 2420            Shannon County SD       NaN       NaN         NaN      NaN
# 2919              Bedford city VA       NaN       NaN         NaN      NaN
#
#       o_county  o_crosswalk o_region_name o_division_name state_fips  \
# 93         NaN  NA-NA-NA-NA           NaN             NaN        NaN
# 2420       NaN  NA-NA-NA-NA           NaN             NaN        NaN
# 2919       NaN  NA-NA-NA-NA           NaN             NaN        NaN
#
#      county_fips region division sumlev
# 93           NaN    NaN      NaN    NaN
# 2420         NaN    NaN      NaN    NaN
# 2919         NaN    NaN      NaN    NaN

# %% [markdown]
# #### Check duplicates

# %% [markdown]
# There are no perfectly duplicated rows.

# %%
sum(fips_df.duplicated())
# Out:
# 0

# %% [markdown]
# There should be one row per county-state pair.

# %%
fips_df["o_long_name"].value_counts()
# Out:
# District of Columbia DC    2
# Gates County NC            1
# Stevens County MN          1
# King George County VA      1
# Osborne County KS          1
#                           ..
# Comanche County OK         1
# Coles County IL            1
# DoÐa Ana County NM         1
# Wells County IN            1
# Suwannee County FL         1
# Name: o_long_name, Length: 3145, dtype: int64

# %% [markdown]
# There appears to be an additional row for Washington, D.C. - one for each value of sumlev (40 and 50).

# %%
fips_df[fips_df["o_long_name"] == "District of Columbia DC"]
# Out:
#      o_fips         o_county_name o_state_abbr          o_state_name  \
# 320   11001  District of Columbia           DC  District of Columbia
# 321   11001  District of Columbia           DC  District of Columbia
#
#                  o_long_name  o_sumlev  o_region  o_division  o_state  \
# 320  District of Columbia DC      40.0       3.0         5.0     11.0
# 321  District of Columbia DC      50.0       3.0         5.0     11.0
#
#      o_county o_crosswalk o_region_name o_division_name state_fips  \
# 320       0.0    3-5-11-0         South  South Atlantic       11.0
# 321       1.0    3-5-11-1         South  South Atlantic       11.0
#
#     county_fips region division sumlev
# 320         0.0    3.0      5.0   40.0
# 321         1.0    3.0      5.0   50.0

# %% [markdown]
# We can remove this row to deduplicate.

# %%
clean_fips_df = fips_df[fips_df["o_sumlev"] != 40]

# %%
clean_fips_df.describe(include = 'all')
# Out:
#               o_fips      o_county_name o_state_abbr o_state_name  \
# count    3145.000000               3145         3145         3145
# unique           NaN               1879           51           51
# top              NaN  Washington County           TX        Texas
# freq             NaN                 30          254          254
# mean    30386.430525                NaN          NaN          NaN
# std     15170.840246                NaN          NaN          NaN
# min      1001.000000                NaN          NaN          NaN
# 25%     18177.000000                NaN          NaN          NaN
# 50%     29177.000000                NaN          NaN          NaN
# 75%     45083.000000                NaN          NaN          NaN
# max     56045.000000                NaN          NaN          NaN
#
#             o_long_name  o_sumlev     o_region   o_division      o_state  \
# count              3145    3142.0  3142.000000  3142.000000  3142.000000
# unique             3145       NaN          NaN          NaN          NaN
# top     Gates County NC       NaN          NaN          NaN          NaN
# freq                  1       NaN          NaN          NaN          NaN
# mean                NaN      50.0     2.668682     5.192553    30.280076
# std                 NaN       0.0     0.803149     1.964060    15.144339
# min                 NaN      50.0     1.000000     1.000000     1.000000
# 25%                 NaN      50.0     2.000000     4.000000    18.000000
# 50%                 NaN      50.0     3.000000     5.000000    29.000000
# 75%                 NaN      50.0     3.000000     7.000000    45.000000
# max                 NaN      50.0     4.000000     9.000000    56.000000
#
#            o_county  o_crosswalk o_region_name     o_division_name  \
# count   3142.000000         3145          3142                3142
# unique          NaN         3143             4                   9
# top             NaN  NA-NA-NA-NA         South  West North Central
# freq            NaN            3          1422                 618
# mean     103.572884          NaN           NaN                 NaN
# std      107.704060          NaN           NaN                 NaN
# min        1.000000          NaN           NaN                 NaN
# 25%       35.000000          NaN           NaN                 NaN
# 50%       79.000000          NaN           NaN                 NaN
# 75%      133.000000          NaN           NaN                 NaN
# max      840.000000          NaN           NaN                 NaN
#
#         state_fips  county_fips  region  division  sumlev
# count       3142.0       3142.0  3142.0    3142.0  3142.0
# unique        51.0        324.0     4.0       9.0     1.0
# top           48.0          1.0     3.0       4.0    50.0
# freq         254.0         49.0  1422.0     618.0  3142.0
# mean           NaN          NaN     NaN       NaN     NaN
# std            NaN          NaN     NaN       NaN     NaN
# min            NaN          NaN     NaN       NaN     NaN
# 25%            NaN          NaN     NaN       NaN     NaN
# 50%            NaN          NaN     NaN       NaN     NaN
# 75%            NaN          NaN     NaN       NaN     NaN
# max            NaN          NaN     NaN       NaN     NaN

# %% [markdown]
# ### Pickle data

# %%
pickle.dump(flattened_covid_df, open( "../Data_pkl/flattened_covid_df.pkl", "wb" ) )
