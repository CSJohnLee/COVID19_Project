# %% [markdown]
# # COVID-19 MIDS Collaboration
#
# ## Data Import: COVID-19 Data
#
# This Jupyter Notebook reads in raw data as csv files and exports them as [pickle files for faster loading](https://medium.com/better-programming/load-fast-load-big-with-compressed-pickles-5f311584507e).

# %% [markdown]
# ### Data sources
#
# COVID-19 data:

# %% [markdown]
# ### Set up environment

# %%
# Import packages
import pandas as pd # to read in csv
import numpy as np # to process data
import pickle # to pickle files

# %% [markdown]
# Here, we import our dataset into a pandas dataframe and add a "o_" prefix to all columsn to demarcate which columns were the originals.

# %%
#Read in data & add "o_" prefix to demarcate which columns were the originals 
# covid cases data
covid_df = pd.read_csv("../Data_raw/us-counties.csv").add_prefix('o_')

# %% [markdown]
# ### Inspect data

# %% [markdown]
# #### Count records

# %% [markdown]
# Our dataset tracking COVID-19 cases and deaths by county has 61,971 rows and 6 columns.

# %%
# count rows and columns
covid_df.shape
# Out:
# (61971, 6)

# %% [markdown]
# #### Check and convert datatypes

# %% [markdown]
# We have:
#
# * one string column tracking the date (which needs to be converted to a date object)
# * 3 float columns tracking location
#     * county and state are correctly stored as strings
#     * fips is a float and should be converted to a category - it should also be split into county and state codes
# * 2 integer columns tracking COVID-19 cases and deaths

# %%
# check data types 
covid_df.dtypes
# Out:
# o_date       object
# o_county     object
# o_state      object
# o_fips      float64
# o_cases       int64
# o_deaths      int64
# dtype: object

# %%
covid_df.head()
# Out:
#        o_date   o_county     o_state   o_fips  o_cases  o_deaths
# 0  2020-01-21  Snohomish  Washington  53061.0        1         0
# 1  2020-01-22  Snohomish  Washington  53061.0        1         0
# 2  2020-01-23  Snohomish  Washington  53061.0        1         0
# 3  2020-01-24       Cook    Illinois  17031.0        1         0
# 4  2020-01-24  Snohomish  Washington  53061.0        1         0

# %%
# create new version of column as a datetime object
covid_df["date"] = pd.to_datetime(covid_df["o_date"])
# check conversion 
covid_df.dtypes
# Out:
# o_date              object
# o_county            object
# o_state             object
# o_fips             float64
# o_cases              int64
# o_deaths             int64
# date        datetime64[ns]
# dtype: object

# %%
# create new version of fips column as nullable integer
covid_df["fips"] = covid_df["o_fips"].astype('category')
# check conversion 
covid_df.dtypes
# Out:
# o_date              object
# o_county            object
# o_state             object
# o_fips             float64
# o_cases              int64
# o_deaths             int64
# date        datetime64[ns]
# fips              category
# dtype: object

# %%
# visual check of column conversions - these worked 
covid_df.head()
# Out:
#        o_date   o_county     o_state   o_fips  o_cases  o_deaths       date  \
# 0  2020-01-21  Snohomish  Washington  53061.0        1         0 2020-01-21
# 1  2020-01-22  Snohomish  Washington  53061.0        1         0 2020-01-22
# 2  2020-01-23  Snohomish  Washington  53061.0        1         0 2020-01-23
# 3  2020-01-24       Cook    Illinois  17031.0        1         0 2020-01-24
# 4  2020-01-24  Snohomish  Washington  53061.0        1         0 2020-01-24
#
#       fips
# 0  53061.0
# 1  53061.0
# 2  53061.0
# 3  17031.0
# 4  53061.0

# %% [markdown]
# ### Check missingness

# %% [markdown]
# We have 807 missing FIPS codes, but no other missing data (at least that is coded as NaNs).

# %%
covid_df.isnull().sum(axis = 0)
# Out:
# o_date        0
# o_county      0
# o_state       0
# o_fips      807
# o_cases       0
# o_deaths      0
# date          0
# fips        807
# dtype: int64

# %% [markdown]
# 3 counties have missing FIPS codes.

# %%
covid_df["o_county"][covid_df["o_fips"].isnull()].unique()
# Out:
# array(['New York City', 'Unknown', 'Kansas City'], dtype=object)

# %% [markdown]
# New York City is comprised of 5 counties (1 for each of the 5 boroughs); these each have their own FIPS codes: New York County (Manhattan), Kings County (Brooklyn), Bronx County (The Bronx), Richmond County (Staten Island), and Queens County (Queens).

# %%
# show unique state for counties coded as "Unknown"
covid_df["o_state"][covid_df["o_county"] == "New York City"].unique()
# Out:
# array(['New York'], dtype=object)

# %%
# show unique fips codes for counties coded as "New York City"
covid_df["o_fips"][covid_df["o_county"] == "New York City"].unique()
# Out:
# array([nan])

# %% [markdown]
# Kansas City, Missouri also straddles multiple counties which would explain why it does not have a FIPS code.

# %%
# show unique states for counties coded as "Kansas City"
covid_df["o_state"][covid_df["o_county"] == "Kansas City"].unique()
# Out:
# array(['Missouri'], dtype=object)

# %%
# show unique fips codes for counties coded as "Kansas City"
covid_df["o_fips"][covid_df["o_county"] == "Kansas City"].unique()
# Out:
# array([nan])

# %% [markdown]
# Other rows are missing FIPS codes because they lack a county (it is marked as "Unknown"). Some would make sense - for example, Puerto Rico only has a state FIPS code.

# %%
# show unique states for counties coded as "Unknown"
covid_df["o_state"][covid_df["o_county"] == "Unknown"].unique()
# Out:
# array(['Rhode Island', 'New Jersey', 'Puerto Rico', 'Virgin Islands',
#        'Guam', 'Maine', 'Massachusetts', 'Louisiana', 'Kentucky',
#        'Nevada', 'Tennessee', 'Arkansas', 'Georgia', 'Missouri',
#        'Minnesota', 'California', 'Colorado', 'Florida', 'Hawaii',
#        'Illinois', 'Vermont', 'Idaho', 'Michigan', 'Ohio', 'Utah',
#        'Mississippi', 'Northern Mariana Islands', 'Nebraska',
#        'Connecticut', 'South Dakota', 'Indiana', 'Alaska', 'Arizona',
#        'New Mexico', 'New York', 'Pennsylvania', 'Virginia',
#        'New Hampshire', 'Washington', 'Delaware', 'Kansas',
#        'North Dakota', 'Maryland'], dtype=object)

# %%
# show unique fips codes for counties coded as "Unknown"
covid_df["o_fips"][covid_df["o_county"] == "Unknown"].unique()
# Out:
# array([nan])

# %% [markdown]
# The missingness in FIPS codes is a major issue since this is the geographic identifier we would use to join these data to other datsets. We will likely need to accurately rectify this missingness in order to accurately combine our data. These don't seem to be erroneous data for the most part. Rather, the missing points reflect when a data point is at the city (rather than county) level and/or if there is no county for that region.

# %%
# replace rows with missing county with NaN 
covid_df["county"] = covid_df["o_county"].replace("Unknown", None)

# %% [markdown]
# ### Generate summary statistics

# %% [markdown]
# The mins and maxes look reasonable for COVID-19 mins and maxes. The distributions are remarkable but also reasonable - we clearly have some outliers on the high end (New York is likely one of those).
#
# We have no missing data in the text columns. We have data for 86 unique days, in 55 "states" (so the data also include territories), and 1,627 counties. In the original county column, we see there are 1,628 unique values since the NaNs used to be coded as "Unknown".
#
# We can see that we have some missing data in our FIPS codes column and that we have 2,708 unique codes.
#
# Our earliest date was January 21st, 2020. Our last was April 15th, 2020.

# %%
# display summary statistics
covid_df.describe(include = 'all')
# Out:
#             o_date    o_county o_state        o_fips        o_cases  \
# count        61971       61971   61971  61164.000000   61971.000000
# unique          86        1628      55           NaN            NaN
# top     2020-04-15  Washington   Texas           NaN            NaN
# freq          2722         772    3685           NaN            NaN
# first          NaN         NaN     NaN           NaN            NaN
# last           NaN         NaN     NaN           NaN            NaN
# mean           NaN         NaN     NaN  29601.488980     121.685353
# std            NaN         NaN     NaN  15528.488936    1520.051958
# min            NaN         NaN     NaN   1001.000000       0.000000
# 25%            NaN         NaN     NaN  17179.000000       2.000000
# 50%            NaN         NaN     NaN  28143.000000       6.000000
# 75%            NaN         NaN     NaN  42131.000000      25.000000
# max            NaN         NaN     NaN  56043.000000  118302.000000
#
#             o_deaths                 date     fips      county
# count   61971.000000                61971  61164.0       61971
# unique           NaN                   86   2708.0        1627
# top              NaN  2020-04-15 00:00:00  53061.0  Washington
# freq             NaN                 2722     86.0         777
# first            NaN  2020-01-21 00:00:00      NaN         NaN
# last             NaN  2020-04-15 00:00:00      NaN         NaN
# mean        4.025415                  NaN      NaN         NaN
# std        82.937968                  NaN      NaN         NaN
# min         0.000000                  NaN      NaN         NaN
# 25%         0.000000                  NaN      NaN         NaN
# 50%         0.000000                  NaN      NaN         NaN
# 75%         1.000000                  NaN      NaN         NaN
# max      8215.000000                  NaN      NaN         NaN

# %% [markdown]
# Now that we have verified our column conversion worked, we drop the columns for which we had added additional columns with the correct data type and remove the "o_" prefix since we no longer need to compare original versus converted columns. Columns are reordered to match the original ordering in the dataset.

# %%
# drop, rename, and reorder columns
converted_covid_df = covid_df.drop(columns = ["o_date", "o_fips", "o_county"]).rename(columns = lambda x: x.replace('o_', ''))[["date", "fips", "county", "state", "cases", "deaths"]]
# visual inspection
converted_covid_df.head()
# Out:
#         date     fips     county       state  cases  deaths
# 0 2020-01-21  53061.0  Snohomish  Washington      1       0
# 1 2020-01-22  53061.0  Snohomish  Washington      1       0
# 2 2020-01-23  53061.0  Snohomish  Washington      1       0
# 3 2020-01-24  17031.0       Cook    Illinois      1       0
# 4 2020-01-24  53061.0  Snohomish  Washington      1       0

# %% [markdown]
# ### Check duplicates

# %% [markdown]
# There are no perfectly duplicated rows.

# %%
sum(converted_covid_df.duplicated())
# Out:
# 0

# %% [markdown]
# There are 2,721 unique county-state pairs.

# %%
# create column to store county-state pairs
converted_covid_df["county_state"] = (converted_covid_df["county"] + ", " + converted_covid_df["state"])
# count unique county-state pairs
len(converted_covid_df["county_state"].unique())
# Out:
# 2721

# %% [markdown]
# Suffolk, Massachusetts appears the most frequently, which is unexpected. It has 20 more entries than there are days in the dataset. The next county is Snohomish, Washington occurs 86 times, which could represent one record per day. Some areas appear only once.

# %%
converted_covid_df["county_state"].value_counts()
# Out:
# Suffolk, Massachusetts     106
# Snohomish, Washington       86
# Cook, Illinois              83
# Orange, California          82
# Los Angeles, California     81
#                           ...
# Norman, Minnesota            1
# Harrison, Ohio               1
# Benzie, Michigan             1
# Alcona, Michigan             1
# Bosque, Texas                1
# Name: county_state, Length: 2721, dtype: int64

# %% [markdown]
# Suffolk, Massachusettes has only 75 reported days.

# %%
len(converted_covid_df["date"][converted_covid_df["county_state"] == "Suffolk, Massachusetts"].unique())
# Out:
# 75

# %% [markdown]
# We can see that the maximum number of unique dates is for Snohomish, Washington (86). We will need to flatten our file so that it is at the date level - so that there is one date per county/state pair.

# %%
# show first 5 rows of dataframe
converted_covid_df.groupby('county_state').date.nunique().reset_index().sort_values('date', ascending = 0).head(5)
# Out:
#                  county_state  date
# 2255    Snohomish, Washington    86
# 548            Cook, Illinois    83
# 1845       Orange, California    82
# 1462  Los Angeles, California    81
# 1528        Maricopa, Arizona    81

# %%
# show first 5 rows of dataframe
converted_covid_df.groupby('county_state').date.nunique().reset_index().sort_values('date', ascending = 0).tail(5)
# Out:
#                   county_state  date
# 1799  Nome Census Area, Alaska     1
# 27            Alcona, Michigan     1
# 1731         Morrill, Nebraska     1
# 1802         Norman, Minnesota     1
# 210            Boundary, Idaho     1

# %%
converted_covid_df[converted_covid_df.duplicated(subset=['county_state', 'date'], keep=False)]
# Out:
#             date     fips    county       state  cases  deaths  \
# 1510  2020-03-12  34039.0     Union  New Jersey      1       0
# 1511  2020-03-12      NaN     Union  New Jersey      1       0
# 1803  2020-03-13  34039.0     Union  New Jersey      1       0
# 1804  2020-03-13      NaN     Union  New Jersey      1       0
# 2150  2020-03-14  34039.0     Union  New Jersey      1       0
# ...          ...      ...       ...         ...    ...     ...
# 61668 2020-04-15      NaN   Rutland     Vermont     12       0
# 61786 2020-04-15  51185.0  Tazewell    Virginia      4       0
# 61787 2020-04-15      NaN  Tazewell    Virginia      0      59
# 61830 2020-04-15  53067.0  Thurston  Washington     82       1
# 61831 2020-04-15      NaN  Thurston  Washington     77       0
#
#                county_state
# 1510      Union, New Jersey
# 1511      Union, New Jersey
# 1803      Union, New Jersey
# 1804      Union, New Jersey
# 2150      Union, New Jersey
# ...                     ...
# 61668      Rutland, Vermont
# 61786    Tazewell, Virginia
# 61787    Tazewell, Virginia
# 61830  Thurston, Washington
# 61831  Thurston, Washington
#
# [1184 rows x 7 columns]

# %% [markdown]
# If these duplicated rows have about 1 extra duplication each, we would expect to drop 592 rows once we flatten.

# %%
converted_covid_df[converted_covid_df.duplicated(subset=['county_state', 'date'], keep=False)].shape[0]/2
# Out:
# 592.0

# %% [markdown]
# We can see that there are discrepancies in case counts on some days  in some counties. It is unclear whether we should add these cases or if one row is accurate.

# %%
# pull out rows for Thurston County, Washington
converted_covid_df[converted_covid_df['county'] == 'Thurston']
# Out:
#             date     fips    county       state  cases  deaths  \
# 1356  2020-03-11  53067.0  Thurston  Washington      1       0
# 1610  2020-03-12  53067.0  Thurston  Washington      1       0
# 1921  2020-03-13  53067.0  Thurston  Washington      3       0
# 2295  2020-03-14  53067.0  Thurston  Washington      3       0
# 2724  2020-03-15  53067.0  Thurston  Washington      4       0
# 3198  2020-03-16  53067.0  Thurston  Washington      4       0
# 3740  2020-03-17  53067.0  Thurston  Washington      5       0
# 4375  2020-03-18  53067.0  Thurston  Washington      6       0
# 5132  2020-03-19  53067.0  Thurston  Washington      6       0
# 6036  2020-03-20  53067.0  Thurston  Washington      8       0
# 7067  2020-03-21  53067.0  Thurston  Washington     10       0
# 8204  2020-03-22  53067.0  Thurston  Washington     11       0
# 9430  2020-03-23  53067.0  Thurston  Washington     11       0
# 10783 2020-03-24  53067.0  Thurston  Washington     14       0
# 12312 2020-03-25  53067.0  Thurston  Washington     14       0
# 13974 2020-03-26  53067.0  Thurston  Washington     24       0
# 15755 2020-03-27  53067.0  Thurston  Washington     27       0
# 17647 2020-03-28  53067.0  Thurston  Washington     33       0
# 19626 2020-03-29  53067.0  Thurston  Washington     36       0
# 21707 2020-03-30  53067.0  Thurston  Washington     43       0
# 23870 2020-03-31  53067.0  Thurston  Washington     48       0
# 26098 2020-04-01  53067.0  Thurston  Washington     51       0
# 28384 2020-04-02  53067.0  Thurston  Washington     55       0
# 30736 2020-04-03  53067.0  Thurston  Washington     58       0
# 33138 2020-04-04  53067.0  Thurston  Washington     64       1
# 35579 2020-04-05  53067.0  Thurston  Washington     67       1
# 38063 2020-04-06  53067.0  Thurston  Washington     72       1
# 38064 2020-04-06      NaN  Thurston  Washington    653       0
# 40595 2020-04-07  53067.0  Thurston  Washington     74       1
# 40596 2020-04-07      NaN  Thurston  Washington    601       0
# 43157 2020-04-08  53067.0  Thurston  Washington     77       1
# 43158 2020-04-08      NaN  Thurston  Washington    705       0
# 45749 2020-04-09  53067.0  Thurston  Washington     81       1
# 45750 2020-04-09      NaN  Thurston  Washington    815       0
# 48377 2020-04-10  53067.0  Thurston  Washington     81       1
# 48378 2020-04-10      NaN  Thurston  Washington    627       0
# 51034 2020-04-11  53067.0  Thurston  Washington     81       1
# 51035 2020-04-11      NaN  Thurston  Washington    583       0
# 53710 2020-04-12  53067.0  Thurston  Washington     81       1
# 53711 2020-04-12      NaN  Thurston  Washington    499       0
# 56402 2020-04-13  53067.0  Thurston  Washington     81       1
# 56403 2020-04-13      NaN  Thurston  Washington    329       0
# 59108 2020-04-14  53067.0  Thurston  Washington     82       1
# 59109 2020-04-14      NaN  Thurston  Washington    220       0
# 61830 2020-04-15  53067.0  Thurston  Washington     82       1
# 61831 2020-04-15      NaN  Thurston  Washington     77       0
#
#                county_state
# 1356   Thurston, Washington
# 1610   Thurston, Washington
# 1921   Thurston, Washington
# 2295   Thurston, Washington
# 2724   Thurston, Washington
# 3198   Thurston, Washington
# 3740   Thurston, Washington
# 4375   Thurston, Washington
# 5132   Thurston, Washington
# 6036   Thurston, Washington
# 7067   Thurston, Washington
# 8204   Thurston, Washington
# 9430   Thurston, Washington
# 10783  Thurston, Washington
# 12312  Thurston, Washington
# 13974  Thurston, Washington
# 15755  Thurston, Washington
# 17647  Thurston, Washington
# 19626  Thurston, Washington
# 21707  Thurston, Washington
# 23870  Thurston, Washington
# 26098  Thurston, Washington
# 28384  Thurston, Washington
# 30736  Thurston, Washington
# 33138  Thurston, Washington
# 35579  Thurston, Washington
# 38063  Thurston, Washington
# 38064  Thurston, Washington
# 40595  Thurston, Washington
# 40596  Thurston, Washington
# 43157  Thurston, Washington
# 43158  Thurston, Washington
# 45749  Thurston, Washington
# 45750  Thurston, Washington
# 48377  Thurston, Washington
# 48378  Thurston, Washington
# 51034  Thurston, Washington
# 51035  Thurston, Washington
# 53710  Thurston, Washington
# 53711  Thurston, Washington
# 56402  Thurston, Washington
# 56403  Thurston, Washington
# 59108  Thurston, Washington
# 59109  Thurston, Washington
# 61830  Thurston, Washington
# 61831  Thurston, Washington

# %% [markdown]
# ### Convert to appropriate level

# %% [markdown]
# Here, we flatten the file so that there is one row per county-state pair for each day. We sum over the cases and deaths for that day to generate a new cases and deaths column.

# %%
# create new dataframe flattened to county-state pair and date level 
flattened_covid_df = converted_covid_df.groupby(['county_state', 'date']).agg(
    {
     'state': 'first',
     'county': 'first',
     'fips': np.unique,
     'cases':np.unique, 
     'deaths':np.unique
    }).reset_index()

# %%
flattened_covid_df.head()
# Out:
#                 county_state       date           state     county       fips  \
# 0  Abbeville, South Carolina 2020-03-19  South Carolina  Abbeville  [45001.0]
# 1  Abbeville, South Carolina 2020-03-20  South Carolina  Abbeville  [45001.0]
# 2  Abbeville, South Carolina 2020-03-21  South Carolina  Abbeville  [45001.0]
# 3  Abbeville, South Carolina 2020-03-22  South Carolina  Abbeville  [45001.0]
# 4  Abbeville, South Carolina 2020-03-23  South Carolina  Abbeville  [45001.0]
#
#   cases deaths
# 0     1      0
# 1     1      0
# 2     1      0
# 3     1      0
# 4     1      0

# %% [markdown]
# We can see that for counties with discrepancies in case counts, the different case counts are put into a list. These may need to be cleaned manually.

# %%
flattened_covid_df[flattened_covid_df['county'] == 'Thurston']
# Out:
#                county_state       date       state    county     fips  \
# 54111  Thurston, Washington 2020-03-11  Washington  Thurston  53067.0
# 54112  Thurston, Washington 2020-03-12  Washington  Thurston  53067.0
# 54113  Thurston, Washington 2020-03-13  Washington  Thurston  53067.0
# 54114  Thurston, Washington 2020-03-14  Washington  Thurston  53067.0
# 54115  Thurston, Washington 2020-03-15  Washington  Thurston  53067.0
# 54116  Thurston, Washington 2020-03-16  Washington  Thurston  53067.0
# 54117  Thurston, Washington 2020-03-17  Washington  Thurston  53067.0
# 54118  Thurston, Washington 2020-03-18  Washington  Thurston  53067.0
# 54119  Thurston, Washington 2020-03-19  Washington  Thurston  53067.0
# 54120  Thurston, Washington 2020-03-20  Washington  Thurston  53067.0
# 54121  Thurston, Washington 2020-03-21  Washington  Thurston  53067.0
# 54122  Thurston, Washington 2020-03-22  Washington  Thurston  53067.0
# 54123  Thurston, Washington 2020-03-23  Washington  Thurston  53067.0
# 54124  Thurston, Washington 2020-03-24  Washington  Thurston  53067.0
# 54125  Thurston, Washington 2020-03-25  Washington  Thurston  53067.0
# 54126  Thurston, Washington 2020-03-26  Washington  Thurston  53067.0
# 54127  Thurston, Washington 2020-03-27  Washington  Thurston  53067.0
# 54128  Thurston, Washington 2020-03-28  Washington  Thurston  53067.0
# 54129  Thurston, Washington 2020-03-29  Washington  Thurston  53067.0
# 54130  Thurston, Washington 2020-03-30  Washington  Thurston  53067.0
# 54131  Thurston, Washington 2020-03-31  Washington  Thurston  53067.0
# 54132  Thurston, Washington 2020-04-01  Washington  Thurston  53067.0
# 54133  Thurston, Washington 2020-04-02  Washington  Thurston  53067.0
# 54134  Thurston, Washington 2020-04-03  Washington  Thurston  53067.0
# 54135  Thurston, Washington 2020-04-04  Washington  Thurston  53067.0
# 54136  Thurston, Washington 2020-04-05  Washington  Thurston  53067.0
# 54137  Thurston, Washington 2020-04-06  Washington  Thurston  53067.0
# 54138  Thurston, Washington 2020-04-07  Washington  Thurston  53067.0
# 54139  Thurston, Washington 2020-04-08  Washington  Thurston  53067.0
# 54140  Thurston, Washington 2020-04-09  Washington  Thurston  53067.0
# 54141  Thurston, Washington 2020-04-10  Washington  Thurston  53067.0
# 54142  Thurston, Washington 2020-04-11  Washington  Thurston  53067.0
# 54143  Thurston, Washington 2020-04-12  Washington  Thurston  53067.0
# 54144  Thurston, Washington 2020-04-13  Washington  Thurston  53067.0
# 54145  Thurston, Washington 2020-04-14  Washington  Thurston  53067.0
# 54146  Thurston, Washington 2020-04-15  Washington  Thurston  53067.0
#
#            cases  deaths  fips0 fips_str state_fips county_fips
# 54111          1       0    NaN    53067         53         067
# 54112          1       0    NaN    53067         53         067
# 54113          3       0    NaN    53067         53         067
# 54114          3       0    NaN    53067         53         067
# 54115          4       0    NaN    53067         53         067
# 54116          4       0    NaN    53067         53         067
# 54117          5       0    NaN    53067         53         067
# 54118          6       0    NaN    53067         53         067
# 54119          6       0    NaN    53067         53         067
# 54120          8       0    NaN    53067         53         067
# 54121         10       0    NaN    53067         53         067
# 54122         11       0    NaN    53067         53         067
# 54123         11       0    NaN    53067         53         067
# 54124         14       0    NaN    53067         53         067
# 54125         14       0    NaN    53067         53         067
# 54126         24       0    NaN    53067         53         067
# 54127         27       0    NaN    53067         53         067
# 54128         33       0    NaN    53067         53         067
# 54129         36       0    NaN    53067         53         067
# 54130         43       0    NaN    53067         53         067
# 54131         48       0    NaN    53067         53         067
# 54132         51       0    NaN    53067         53         067
# 54133         55       0    NaN    53067         53         067
# 54134         58       0    NaN    53067         53         067
# 54135         64       1    NaN    53067         53         067
# 54136         67       1    NaN    53067         53         067
# 54137  [72, 653]  [0, 1]    NaN    53067         53         067
# 54138  [74, 601]  [0, 1]    NaN    53067         53         067
# 54139  [77, 705]  [0, 1]    NaN    53067         53         067
# 54140  [81, 815]  [0, 1]    NaN    53067         53         067
# 54141  [81, 627]  [0, 1]    NaN    53067         53         067
# 54142  [81, 583]  [0, 1]    NaN    53067         53         067
# 54143  [81, 499]  [0, 1]    NaN    53067         53         067
# 54144  [81, 329]  [0, 1]    NaN    53067         53         067
# 54145  [82, 220]  [0, 1]    NaN    53067         53         067
# 54146   [77, 82]  [0, 1]    NaN    53067         53         067

# %% [markdown]
# The fips column can be split into a column of fips and a column of NAs because some rows had the county-state identifier and date but did not have a fips code.

# %%
# split columns
flattened_covid_df[['fips','fips0']] = pd.DataFrame(flattened_covid_df.fips.values.tolist(), index= flattened_covid_df.index)

# check that new column is only NAs 
sum(flattened_covid_df['fips0'].notna())
# Out:
# 0

# %%
# create new version of fips column as string 
flattened_covid_df["fips_str"] = flattened_covid_df["fips"].astype('Int64').astype('str')

# %%
# extract state FIPS and convert to category 
flattened_covid_df["state_fips"] = flattened_covid_df["fips_str"].apply(lambda x: x[:-3]).astype('category')
flattened_covid_df["state_fips"].head()
# Out:
# 0    45
# 1    45
# 2    45
# 3    45
# 4    45
# Name: state_fips, dtype: category
# Categories (52, object): [, 1, 10, 11, ..., 56, 6, 8, 9]

# %%
# extract county FIPS and convert to category 
flattened_covid_df["county_fips"] = flattened_covid_df["fips_str"].apply(lambda x: x[-3:]).astype('category')
flattened_covid_df["county_fips"].head()
# Out:
# 0    001
# 1    001
# 2    001
# 3    001
# 4    001
# Name: county_fips, dtype: category
# Categories (284, object): [001, 003, 005, 006, ..., 820, 830, 840, nan]

# %% [markdown]
# We can see that we have dropped 592 rows, which is about what we expected in flattening the files.

# %%
# check new shape
covid_df.shape[0] - flattened_covid_df.shape[0]
# Out:
# 592

# %% [markdown]
# ### Pickle data

# %%
pickle.dump(flattened_covid_df, open( "../Data_pkl/flattened_covid_df.pkl", "wb" ) )
